# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
import datetime
from scipy.stats import linregress
import os 
from api_keys import g_key


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 644

# %%
cities
# Out:
# ['kazalinsk',
#  'fortuna',
#  'ushuaia',
#  'yako',
#  'mataura',
#  'new norfolk',
#  'alofi',
#  'monrovia',
#  'bredasdorp',
#  'abyek',
#  'qaanaaq',
#  'taolanaro',
#  'rawson',
#  'lebu',
#  'marienburg',
#  'albany',
#  'thompson',
#  'kaeo',
#  'carnarvon',
#  'awjilah',
#  'hilo',
#  'hermanus',
#  'mahebourg',
#  'atuona',
#  'okhotsk',
#  'georgetown',
#  'cherskiy',
#  'urubicha',
#  'cape town',
#  'tasiilaq',
#  'sironko',
#  'ixtapa',
#  'mehriz',
#  'busselton',
#  'upernavik',
#  'port elizabeth',
#  'viedma',
#  'babat',
#  'joshimath',
#  'ust-omchug',
#  'lais',
#  'jamestown',
#  'buala',
#  'illoqqortoormiut',
#  'yellowknife',
#  'mount isa',
#  'beloha',
#  'mankono',
#  'camacha',
#  'mys shmidta',
#  'zachagansk',
#  'gangotri',
#  'algiers',
#  'saint-leu',
#  'rikitea',
#  'arraial do cabo',
#  'mmabatho',
#  'goulburn',
#  'gravdal',
#  'hongjiang',
#  'harper',
#  'bluff',
#  'nizhniy baskunchak',
#  'punta arenas',
#  'vestmannaeyjar',
#  'olafsvik',
#  'barrow',
#  'katherine',
#  'luba',
#  'dikson',
#  'vaini',
#  'el alto',
#  'tsihombe',
#  'petrozavodsk',
#  'port lincoln',
#  'bac lieu',
#  'vaitupu',
#  'bustonkala',
#  'zhanaozen',
#  'castro',
#  'agadez',
#  'saint george',
#  'wasilla',
#  'acajutla',
#  'fairbanks',
#  'inta',
#  'kavieng',
#  'belushya guba',
#  'tuktoyaktuk',
#  'ales',
#  'gat',
#  'sechura',
#  'coatzintla',
#  'ust-tsilma',
#  'homer',
#  'kaitangata',
#  'kruisfontein',
#  'cabo san lucas',
#  'yunjinghong',
#  'port hardy',
#  'mar del plata',
#  'wajima',
#  'hobart',
#  'chapleau',
#  'nikolskoye',
#  'naryan-mar',
#  'salalah',
#  'nicoya',
#  'tumannyy',
#  'road town',
#  'ribeira grande',
#  'santa rosa',
#  'kefar shemaryahu',
#  'katsuura',
#  'zakharo',
#  'beyneu',
#  'cloquet',
#  'bambanglipuro',
#  'gafanha da encarnacao',
#  'bambous virieux',
#  'sambava',
#  'victoria',
#  'labe',
#  'talnakh',
#  'nizhneyansk',
#  'kulevcha',
#  'clyde river',
#  'burntwood',
#  'goya',
#  'manaure',
#  'aksehir',
#  'nouadhibou',
#  'surin',
#  'pingdingshan',
#  'temaraia',
#  'atocha',
#  'bolgatanga',
#  'namibe',
#  'kushmurun',
#  'north bend',
#  'santa isabel do rio negro',
#  'atamanovka',
#  'port augusta',
#  'guerrero negro',
#  'avarua',
#  'shumskiy',
#  'atikokan',
#  'chokurdakh',
#  'amderma',
#  'bethel',
#  'vanavara',
#  'khatanga',
#  'matane',
#  'touros',
#  'razole',
#  'luwuk',
#  'ust-barguzin',
#  'san cristobal',
#  'bahia honda',
#  'faanui',
#  'henties bay',
#  'tilichiki',
#  'anadyr',
#  'leningradskiy',
#  'east london',
#  'port-cartier',
#  'klaksvik',
#  'biltine',
#  'pacific grove',
#  'kenai',
#  'port alfred',
#  'sumbawa',
#  'fowa',
#  'lima',
#  'san esteban',
#  'chara',
#  'hambantota',
#  'mikuni',
#  'ust-kuyga',
#  'constitucion',
#  'pisco',
#  'akyab',
#  'namatanai',
#  'narsaq',
#  'maroantsetra',
#  'qui nhon',
#  'gazojak',
#  'lompoc',
#  'tateyama',
#  'constantine',
#  'ponta do sol',
#  'santa cruz',
#  'tomatlan',
#  'bago',
#  'flinders',
#  'dunedin',
#  'rokupr',
#  'sitka',
#  'ngunguru',
#  'anito',
#  'murud',
#  'bubaque',
#  'beringovskiy',
#  'kodiak',
#  'havelock',
#  'kalomo',
#  'bilibino',
#  'margate',
#  'kodino',
#  'sibolga',
#  'sidney',
#  'bengkulu',
#  'coahuayana',
#  'vanimo',
#  'sungaipenuh',
#  'praia da vitoria',
#  'norman wells',
#  'arrecife',
#  'laguna',
#  'provideniya',
#  'shiraz',
#  'te anau',
#  'saleaula',
#  'port-de-bouc',
#  'acarau',
#  'ostrovnoy',
#  'najran',
#  'hithadhoo',
#  'butaritari',
#  'quatre cocos',
#  'geraldton',
#  'tynset',
#  'vardo',
#  'tromso',
#  'kyzyl-suu',
#  'vila franca do campo',
#  'egvekinot',
#  'grand river south east',
#  'moree',
#  'ceres',
#  'puerto ayora',
#  'shimoda',
#  'dobrinka',
#  'caravelas',
#  'gouloure',
#  'rawannawi',
#  'lagoa',
#  'ambagarh chauki',
#  'hattiesburg',
#  'kapaa',
#  'itarema',
#  'ketchikan',
#  'oshnaviyeh',
#  'noyabrsk',
#  'channel-port aux basques',
#  'mackay',
#  'byron bay',
#  'sasykoli',
#  'belyy yar',
#  'axim',
#  'paysandu',
#  'guanay',
#  'tigil',
#  'aksu',
#  'molo',
#  'saint-philippe',
#  'pemba',
#  'progreso',
#  'saldanha',
#  'brae',
#  'sanok',
#  'montes altos',
#  'pangnirtung',
#  'atlantic city',
#  'maragogi',
#  'avera',
#  'lichinga',
#  'souillac',
#  'sao felix do xingu',
#  'uthal',
#  'wairoa',
#  'bonavista',
#  'alyangula',
#  'arlit',
#  'los llanos de aridane',
#  'padang',
#  'komsomolskiy',
#  'tres lagoas',
#  'sao joao da barra',
#  'mayo',
#  'grindavik',
#  'vila velha',
#  'barentsburg',
#  'suntar',
#  'aberdeen',
#  'ahipara',
#  'ornskoldsvik',
#  'ust-kamchatsk',
#  'benidorm',
#  'nachalovo',
#  'ialibu',
#  'codrington',
#  'kroya',
#  'havre-saint-pierre',
#  'andenes',
#  'carahue',
#  'jalingo',
#  'sorvag',
#  'mitu',
#  'auki',
#  'palana',
#  'birao',
#  'phalodi',
#  'saint-georges',
#  'pevek',
#  'lodwar',
#  'qasigiannguit',
#  'donegal',
#  'airai',
#  'la ronge',
#  'severo-yeniseyskiy',
#  'myitkyina',
#  'datong',
#  'damietta',
#  'matara',
#  'san felipe',
#  'portland',
#  'hinesburg',
#  'gdov',
#  'kulhudhuffushi',
#  'mahon',
#  'srednekolymsk',
#  'torbay',
#  'palabuhanratu',
#  'buraydah',
#  'jertih',
#  'poum',
#  'carnot',
#  'rosarito',
#  'karaton',
#  'cidreira',
#  'menongue',
#  'vallenar',
#  'ponta delgada',
#  'antofagasta',
#  'champerico',
#  'kuminskiy',
#  'kaoma',
#  'libreville',
#  'lazaro cardenas',
#  'baherden',
#  'bull savanna',
#  'devils lake',
#  'zambezi',
#  'sinnamary',
#  'hofn',
#  'longyearbyen',
#  'moose factory',
#  'taburi',
#  'luang prabang',
#  'derzhavinsk',
#  'chuy',
#  'khiv',
#  'rundu',
#  'mpraeso',
#  'paradwip',
#  'gurskoye',
#  'moulins',
#  'iralaya',
#  'igrim',
#  'kawalu',
#  'bathsheba',
#  'diamantina',
#  'warqla',
#  'gusau',
#  'ende',
#  'umm lajj',
#  'yarim',
#  'tarrega',
#  'mogadishu',
#  'vredendal',
#  'pokaran',
#  'toliary',
#  'hamilton',
#  'shahr-e babak',
#  'roma',
#  'samusu',
#  'negombo',
#  'harjavalta',
#  'yarmouth',
#  'faya',
#  'maceio',
#  'attawapiskat',
#  'tessalit',
#  'oum hadjer',
#  'svetlaya',
#  'hede',
#  'boulsa',
#  'alabino',
#  'frankfort',
#  'bac ninh',
#  'kumluca',
#  'jumla',
#  'husavik',
#  'honiara',
#  'conceicao do araguaia',
#  'port-de-paix',
#  'guapore',
#  'san jeronimo',
#  'samarai',
#  'tooele',
#  'yatou',
#  'lakatoro',
#  'nouakchott',
#  'luderitz',
#  'yaring',
#  'nemuro',
#  'kintinku',
#  'salekhard',
#  'christchurch',
#  'hasaki',
#  'bargal',
#  'tabuk',
#  'lasa',
#  'kuruksay',
#  'marcona',
#  'sao domingos',
#  'kahului',
#  'elko',
#  'umzimvubu',
#  'san luis',
#  'labutta',
#  'fare',
#  'belmonte',
#  'arenzano',
#  'jinka',
#  'zhuanghe',
#  'lata',
#  'meridian',
#  'douglas',
#  'sur',
#  'koraput',
#  'saskylakh',
#  'copiapo',
#  'port keats',
#  'dakoro',
#  'maumere',
#  'kouroussa',
#  'arklow',
#  'tura',
#  'marovoay',
#  'karpogory',
#  'barcelos',
#  'eenhana',
#  'chabahar',
#  'labuhan',
#  'juneau',
#  'louisbourg',
#  'olen',
#  'mizdah',
#  'dingle',
#  'vao',
#  'port-gentil',
#  'bogorodskoye',
#  'krasnyy yar',
#  'casper',
#  'coquimbo',
#  'paluan',
#  'kavaratti',
#  'aparecida',
#  'russell',
#  'sao filipe',
#  'tuy hoa',
#  'apucarana',
#  'le havre',
#  'kobe',
#  'qeshm',
#  'iskateley',
#  'katima mulilo',
#  'zunyi',
#  'dalby',
#  'tralee',
#  'namtsy',
#  'mount gambier',
#  'zhigansk',
#  'balkanabat',
#  'jizan',
#  'grafton',
#  'bandarbeyla',
#  'noumea',
#  'nyurba',
#  'meulaboh',
#  'malatya',
#  'suzhou',
#  'erbaa',
#  'honningsvag',
#  'new richmond',
#  'lesozavodsk',
#  'isangel',
#  'mariinskiy posad',
#  'yulara',
#  'keta',
#  'pochutla',
#  'toftir',
#  'mago',
#  'inirida',
#  'mehamn',
#  'immenstadt',
#  'podor',
#  'pingliang',
#  'tottori',
#  'jenison',
#  'tabou',
#  'grand gaube',
#  'tual',
#  'yar-sale',
#  'tlahualilo',
#  'tuatapere',
#  'along',
#  'karauzyak',
#  'oranjestad',
#  'severo-kurilsk',
#  'horki',
#  'lewisporte',
#  'ipixuna',
#  'labrea',
#  'sola',
#  'neiafu',
#  'dzerzhinsk',
#  'punta alta',
#  'carndonagh',
#  'cockburn town',
#  'kununurra',
#  'aniva',
#  'college',
#  'nalut',
#  'sherlovaya gora',
#  'imbituba',
#  'wapi pathum',
#  'creel',
#  'vagur',
#  'hobyo',
#  'bundibugyo',
#  'bontang',
#  'cayenne',
#  'tiksi',
#  'nogliki',
#  'deputatskiy',
#  'hervey bay',
#  'malindi',
#  'aktash',
#  'pombal',
#  'terra santa',
#  'coihaique',
#  'zyryanka',
#  'gospic',
#  'springbok',
#  'hami',
#  'jiuquan',
#  'beloye',
#  'valleyview',
#  'jasper',
#  'campbell river',
#  'bushenyi',
#  'maridi',
#  'dhidhdhoo',
#  'dagana',
#  'ape',
#  'houma',
#  'san lorenzo',
#  'waipawa',
#  'mentok',
#  'chimbote',
#  'fenoarivo',
#  'sumbe',
#  'san patricio',
#  'las vegas',
#  'broome',
#  'madimba',
#  'esperance',
#  'nuuk',
#  'jacmel',
#  'churapcha',
#  'pangody',
#  'muros',
#  'ayorou',
#  'caucaia',
#  'montrose',
#  'palasa',
#  'beidao',
#  'ciudad bolivar',
#  'ust-nera',
#  'norrtalje',
#  'conde',
#  'grand centre',
#  'ondjiva',
#  'puerto leguizamo',
#  'laiwu',
#  'bafata',
#  'pacatuba',
#  'shingu',
#  'cabra',
#  'allapalli',
#  'yuzhno-yeniseyskiy',
#  'kalmunai',
#  'cape coast',
#  'ambodifototra',
#  'tolaga bay',
#  'changji',
#  'petatlan',
#  'flin flon',
#  'omboue',
#  'puerto escondido',
#  'krasnoyarsk-66',
#  'rio cuarto',
#  'kysyl-syr',
#  'esso',
#  'atbasar',
#  'port macquarie',
#  'abeche',
#  'ziro',
#  'sao jose da coroa grande',
#  'tanout',
#  'kosonsoy',
#  'pitkyaranta',
#  'salta',
#  'maxixe',
#  'sioux lookout',
#  'ancud',
#  'lashio',
#  'loikaw',
#  'port hawkesbury',
#  'yuli',
#  'chaman',
#  'sulangan',
#  'the pas',
#  'garden city',
#  'richards bay',
#  'kushima',
#  'pringsewu',
#  'meyungs',
#  'hermiston',
#  'abbeville',
#  'little current']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_loc = []
city_counter = 1
city_set = 1

#loop through city list(count=creating set)
for count,ele in enumerate(cities): 
    print (count,ele)
    #grouping the cities in sets of 50.
    if (count % 50 == 0 and count >= 50):
        city_set += 1
        city_counter = 0

        
    #adding to the end of the url(ele=city names)
    city_url = url + "&q=" + ele
    print("Processing Record %s of Set %s | %s" % (city_counter, city_set, ele))
    
    #increase city counter
    city_counter += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weath = requests.get(city_url).json()
        
        #country, lon, lat, temp, humidity, cloud factor, wind, date
        country= city_weath["sys"]["country"]
        date= city_weath["dt"]
        lon= city_weath["coord"]["lon"]
        lat= city_weath["coord"]["lat"]
        temp = city_weath["main"]["temp_max"]
        humidity = city_weath["main"]["humidity"]
        cloud_factor = city_weath["clouds"]["all"]
        wind = city_weath["wind"]["speed"]
        
        #append info above into a dict.
        
        city_loc.append({"City":ele,
                        "Country":country,
                        "Date":date,
                        "Longitude":lon,
                        "Latitude":lat,
                        "Max Temperature":temp,
                        "Humidity": humidity,
                        "Cloudiness": cloud_factor,
                        "Wind speed": wind})
        # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Out:
# 0 kazalinsk
# Processing Record 1 of Set 1 | kazalinsk
# City not found. Skipping...
# 1 fortuna
# Processing Record 2 of Set 1 | fortuna
# 2 ushuaia
# Processing Record 3 of Set 1 | ushuaia
# 3 yako
# Processing Record 4 of Set 1 | yako
# 4 mataura
# Processing Record 5 of Set 1 | mataura
# 5 new norfolk
# Processing Record 6 of Set 1 | new norfolk
# 6 alofi
# Processing Record 7 of Set 1 | alofi
# 7 monrovia
# Processing Record 8 of Set 1 | monrovia
# 8 bredasdorp
# Processing Record 9 of Set 1 | bredasdorp
# 9 abyek
# Processing Record 10 of Set 1 | abyek
# 10 qaanaaq
# Processing Record 11 of Set 1 | qaanaaq
# 11 taolanaro
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# 12 rawson
# Processing Record 13 of Set 1 | rawson
# 13 lebu
# Processing Record 14 of Set 1 | lebu
# 14 marienburg
# Processing Record 15 of Set 1 | marienburg
# 15 albany
# Processing Record 16 of Set 1 | albany
# 16 thompson
# Processing Record 17 of Set 1 | thompson
# 17 kaeo
# Processing Record 18 of Set 1 | kaeo
# 18 carnarvon
# Processing Record 19 of Set 1 | carnarvon
# 19 awjilah
# Processing Record 20 of Set 1 | awjilah
# 20 hilo
# Processing Record 21 of Set 1 | hilo
# 21 hermanus
# Processing Record 22 of Set 1 | hermanus
# 22 mahebourg
# Processing Record 23 of Set 1 | mahebourg
# 23 atuona
# Processing Record 24 of Set 1 | atuona
# 24 okhotsk
# Processing Record 25 of Set 1 | okhotsk
# 25 georgetown
# Processing Record 26 of Set 1 | georgetown
# 26 cherskiy
# Processing Record 27 of Set 1 | cherskiy
# 27 urubicha
# Processing Record 28 of Set 1 | urubicha
# 28 cape town
# Processing Record 29 of Set 1 | cape town
# 29 tasiilaq
# Processing Record 30 of Set 1 | tasiilaq
# 30 sironko
# Processing Record 31 of Set 1 | sironko
# 31 ixtapa
# Processing Record 32 of Set 1 | ixtapa
# 32 mehriz
# Processing Record 33 of Set 1 | mehriz
# 33 busselton
# Processing Record 34 of Set 1 | busselton
# 34 upernavik
# Processing Record 35 of Set 1 | upernavik
# 35 port elizabeth
# Processing Record 36 of Set 1 | port elizabeth
# 36 viedma
# Processing Record 37 of Set 1 | viedma
# 37 babat
# Processing Record 38 of Set 1 | babat
# 38 joshimath
# Processing Record 39 of Set 1 | joshimath
# 39 ust-omchug
# Processing Record 40 of Set 1 | ust-omchug
# 40 lais
# Processing Record 41 of Set 1 | lais
# 41 jamestown
# Processing Record 42 of Set 1 | jamestown
# 42 buala
# Processing Record 43 of Set 1 | buala
# 43 illoqqortoormiut
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# 44 yellowknife
# Processing Record 45 of Set 1 | yellowknife
# 45 mount isa
# Processing Record 46 of Set 1 | mount isa
# 46 beloha
# Processing Record 47 of Set 1 | beloha
# 47 mankono
# Processing Record 48 of Set 1 | mankono
# 48 camacha
# Processing Record 49 of Set 1 | camacha
# 49 mys shmidta
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# 50 zachagansk
# Processing Record 0 of Set 2 | zachagansk
# City not found. Skipping...
# 51 gangotri
# Processing Record 1 of Set 2 | gangotri
# City not found. Skipping...
# 52 algiers
# Processing Record 2 of Set 2 | algiers
# 53 saint-leu
# Processing Record 3 of Set 2 | saint-leu
# 54 rikitea
# Processing Record 4 of Set 2 | rikitea
# 55 arraial do cabo
# Processing Record 5 of Set 2 | arraial do cabo
# 56 mmabatho
# Processing Record 6 of Set 2 | mmabatho
# 57 goulburn
# Processing Record 7 of Set 2 | goulburn
# 58 gravdal
# Processing Record 8 of Set 2 | gravdal
# 59 hongjiang
# Processing Record 9 of Set 2 | hongjiang
# 60 harper
# Processing Record 10 of Set 2 | harper
# 61 bluff
# Processing Record 11 of Set 2 | bluff
# 62 nizhniy baskunchak
# Processing Record 12 of Set 2 | nizhniy baskunchak
# 63 punta arenas
# Processing Record 13 of Set 2 | punta arenas
# 64 vestmannaeyjar
# Processing Record 14 of Set 2 | vestmannaeyjar
# 65 olafsvik
# Processing Record 15 of Set 2 | olafsvik
# 66 barrow
# Processing Record 16 of Set 2 | barrow
# 67 katherine
# Processing Record 17 of Set 2 | katherine
# 68 luba
# Processing Record 18 of Set 2 | luba
# 69 dikson
# Processing Record 19 of Set 2 | dikson
# 70 vaini
# Processing Record 20 of Set 2 | vaini
# 71 el alto
# Processing Record 21 of Set 2 | el alto
# 72 tsihombe
# Processing Record 22 of Set 2 | tsihombe
# City not found. Skipping...
# 73 petrozavodsk
# Processing Record 23 of Set 2 | petrozavodsk
# 74 port lincoln
# Processing Record 24 of Set 2 | port lincoln
# 75 bac lieu
# Processing Record 25 of Set 2 | bac lieu
# 76 vaitupu
# Processing Record 26 of Set 2 | vaitupu
# City not found. Skipping...
# 77 bustonkala
# Processing Record 27 of Set 2 | bustonkala
# City not found. Skipping...
# 78 zhanaozen
# Processing Record 28 of Set 2 | zhanaozen
# 79 castro
# Processing Record 29 of Set 2 | castro
# 80 agadez
# Processing Record 30 of Set 2 | agadez
# 81 saint george
# Processing Record 31 of Set 2 | saint george
# 82 wasilla
# Processing Record 32 of Set 2 | wasilla
# 83 acajutla
# Processing Record 33 of Set 2 | acajutla
# 84 fairbanks
# Processing Record 34 of Set 2 | fairbanks
# 85 inta
# Processing Record 35 of Set 2 | inta
# 86 kavieng
# Processing Record 36 of Set 2 | kavieng
# 87 belushya guba
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# 88 tuktoyaktuk
# Processing Record 38 of Set 2 | tuktoyaktuk
# 89 ales
# Processing Record 39 of Set 2 | ales
# 90 gat
# Processing Record 40 of Set 2 | gat
# 91 sechura
# Processing Record 41 of Set 2 | sechura
# 92 coatzintla
# Processing Record 42 of Set 2 | coatzintla
# 93 ust-tsilma
# Processing Record 43 of Set 2 | ust-tsilma
# 94 homer
# Processing Record 44 of Set 2 | homer
# 95 kaitangata
# Processing Record 45 of Set 2 | kaitangata
# 96 kruisfontein
# Processing Record 46 of Set 2 | kruisfontein
# 97 cabo san lucas
# Processing Record 47 of Set 2 | cabo san lucas
# 98 yunjinghong
# Processing Record 48 of Set 2 | yunjinghong
# City not found. Skipping...
# 99 port hardy
# Processing Record 49 of Set 2 | port hardy
# 100 mar del plata
# Processing Record 0 of Set 3 | mar del plata
# 101 wajima
# Processing Record 1 of Set 3 | wajima
# 102 hobart
# Processing Record 2 of Set 3 | hobart
# 103 chapleau
# Processing Record 3 of Set 3 | chapleau
# 104 nikolskoye
# Processing Record 4 of Set 3 | nikolskoye
# 105 naryan-mar
# Processing Record 5 of Set 3 | naryan-mar
# 106 salalah
# Processing Record 6 of Set 3 | salalah
# 107 nicoya
# Processing Record 7 of Set 3 | nicoya
# 108 tumannyy
# Processing Record 8 of Set 3 | tumannyy
# City not found. Skipping...
# 109 road town
# Processing Record 9 of Set 3 | road town
# 110 ribeira grande
# Processing Record 10 of Set 3 | ribeira grande
# 111 santa rosa
# Processing Record 11 of Set 3 | santa rosa
# 112 kefar shemaryahu
# Processing Record 12 of Set 3 | kefar shemaryahu
# 113 katsuura
# Processing Record 13 of Set 3 | katsuura
# 114 zakharo
# Processing Record 14 of Set 3 | zakharo
# City not found. Skipping...
# 115 beyneu
# Processing Record 15 of Set 3 | beyneu
# 116 cloquet
# Processing Record 16 of Set 3 | cloquet
# 117 bambanglipuro
# Processing Record 17 of Set 3 | bambanglipuro
# 118 gafanha da encarnacao
# Processing Record 18 of Set 3 | gafanha da encarnacao
# 119 bambous virieux
# Processing Record 19 of Set 3 | bambous virieux
# 120 sambava
# Processing Record 20 of Set 3 | sambava
# 121 victoria
# Processing Record 21 of Set 3 | victoria
# 122 labe
# Processing Record 22 of Set 3 | labe
# 123 talnakh
# Processing Record 23 of Set 3 | talnakh
# 124 nizhneyansk
# Processing Record 24 of Set 3 | nizhneyansk
# City not found. Skipping...
# 125 kulevcha
# Processing Record 25 of Set 3 | kulevcha
# 126 clyde river
# Processing Record 26 of Set 3 | clyde river
# 127 burntwood
# Processing Record 27 of Set 3 | burntwood
# 128 goya
# Processing Record 28 of Set 3 | goya
# 129 manaure
# Processing Record 29 of Set 3 | manaure
# 130 aksehir
# Processing Record 30 of Set 3 | aksehir
# 131 nouadhibou
# Processing Record 31 of Set 3 | nouadhibou
# 132 surin
# Processing Record 32 of Set 3 | surin
# 133 pingdingshan
# Processing Record 33 of Set 3 | pingdingshan
# 134 temaraia
# Processing Record 34 of Set 3 | temaraia
# City not found. Skipping...
# 135 atocha
# Processing Record 35 of Set 3 | atocha
# 136 bolgatanga
# Processing Record 36 of Set 3 | bolgatanga
# 137 namibe
# Processing Record 37 of Set 3 | namibe
# 138 kushmurun
# Processing Record 38 of Set 3 | kushmurun
# 139 north bend
# Processing Record 39 of Set 3 | north bend
# 140 santa isabel do rio negro
# Processing Record 40 of Set 3 | santa isabel do rio negro
# 141 atamanovka
# Processing Record 41 of Set 3 | atamanovka
# 142 port augusta
# Processing Record 42 of Set 3 | port augusta
# 143 guerrero negro
# Processing Record 43 of Set 3 | guerrero negro
# 144 avarua
# Processing Record 44 of Set 3 | avarua
# 145 shumskiy
# Processing Record 45 of Set 3 | shumskiy
# 146 atikokan
# Processing Record 46 of Set 3 | atikokan
# 147 chokurdakh
# Processing Record 47 of Set 3 | chokurdakh
# 148 amderma
# Processing Record 48 of Set 3 | amderma
# City not found. Skipping...
# 149 bethel
# Processing Record 49 of Set 3 | bethel
# 150 vanavara
# Processing Record 0 of Set 4 | vanavara
# 151 khatanga
# Processing Record 1 of Set 4 | khatanga
# 152 matane
# Processing Record 2 of Set 4 | matane
# 153 touros
# Processing Record 3 of Set 4 | touros
# 154 razole
# Processing Record 4 of Set 4 | razole
# 155 luwuk
# Processing Record 5 of Set 4 | luwuk
# 156 ust-barguzin
# Processing Record 6 of Set 4 | ust-barguzin
# 157 san cristobal
# Processing Record 7 of Set 4 | san cristobal
# 158 bahia honda
# Processing Record 8 of Set 4 | bahia honda
# 159 faanui
# Processing Record 9 of Set 4 | faanui
# 160 henties bay
# Processing Record 10 of Set 4 | henties bay
# 161 tilichiki
# Processing Record 11 of Set 4 | tilichiki
# 162 anadyr
# Processing Record 12 of Set 4 | anadyr
# 163 leningradskiy
# Processing Record 13 of Set 4 | leningradskiy
# 164 east london
# Processing Record 14 of Set 4 | east london
# 165 port-cartier
# Processing Record 15 of Set 4 | port-cartier
# 166 klaksvik
# Processing Record 16 of Set 4 | klaksvik
# 167 biltine
# Processing Record 17 of Set 4 | biltine
# 168 pacific grove
# Processing Record 18 of Set 4 | pacific grove
# 169 kenai
# Processing Record 19 of Set 4 | kenai
# 170 port alfred
# Processing Record 20 of Set 4 | port alfred
# 171 sumbawa
# Processing Record 21 of Set 4 | sumbawa
# City not found. Skipping...
# 172 fowa
# Processing Record 22 of Set 4 | fowa
# 173 lima
# Processing Record 23 of Set 4 | lima
# 174 san esteban
# Processing Record 24 of Set 4 | san esteban
# 175 chara
# Processing Record 25 of Set 4 | chara
# 176 hambantota
# Processing Record 26 of Set 4 | hambantota
# 177 mikuni
# Processing Record 27 of Set 4 | mikuni
# 178 ust-kuyga
# Processing Record 28 of Set 4 | ust-kuyga
# 179 constitucion
# Processing Record 29 of Set 4 | constitucion
# 180 pisco
# Processing Record 30 of Set 4 | pisco
# 181 akyab
# Processing Record 31 of Set 4 | akyab
# 182 namatanai
# Processing Record 32 of Set 4 | namatanai
# 183 narsaq
# Processing Record 33 of Set 4 | narsaq
# 184 maroantsetra
# Processing Record 34 of Set 4 | maroantsetra
# 185 qui nhon
# Processing Record 35 of Set 4 | qui nhon
# 186 gazojak
# Processing Record 36 of Set 4 | gazojak
# 187 lompoc
# Processing Record 37 of Set 4 | lompoc
# 188 tateyama
# Processing Record 38 of Set 4 | tateyama
# 189 constantine
# Processing Record 39 of Set 4 | constantine
# 190 ponta do sol
# Processing Record 40 of Set 4 | ponta do sol
# 191 santa cruz
# Processing Record 41 of Set 4 | santa cruz
# 192 tomatlan
# Processing Record 42 of Set 4 | tomatlan
# 193 bago
# Processing Record 43 of Set 4 | bago
# 194 flinders
# Processing Record 44 of Set 4 | flinders
# 195 dunedin
# Processing Record 45 of Set 4 | dunedin
# 196 rokupr
# Processing Record 46 of Set 4 | rokupr
# 197 sitka
# Processing Record 47 of Set 4 | sitka
# 198 ngunguru
# Processing Record 48 of Set 4 | ngunguru
# 199 anito
# Processing Record 49 of Set 4 | anito
# 200 murud
# Processing Record 0 of Set 5 | murud
# 201 bubaque
# Processing Record 1 of Set 5 | bubaque
# 202 beringovskiy
# Processing Record 2 of Set 5 | beringovskiy
# 203 kodiak
# Processing Record 3 of Set 5 | kodiak
# 204 havelock
# Processing Record 4 of Set 5 | havelock
# 205 kalomo
# Processing Record 5 of Set 5 | kalomo
# City not found. Skipping...
# 206 bilibino
# Processing Record 6 of Set 5 | bilibino
# 207 margate
# Processing Record 7 of Set 5 | margate
# 208 kodino
# Processing Record 8 of Set 5 | kodino
# 209 sibolga
# Processing Record 9 of Set 5 | sibolga
# 210 sidney
# Processing Record 10 of Set 5 | sidney
# 211 bengkulu
# Processing Record 11 of Set 5 | bengkulu
# 212 coahuayana
# Processing Record 12 of Set 5 | coahuayana
# 213 vanimo
# Processing Record 13 of Set 5 | vanimo
# 214 sungaipenuh
# Processing Record 14 of Set 5 | sungaipenuh
# 215 praia da vitoria
# Processing Record 15 of Set 5 | praia da vitoria
# 216 norman wells
# Processing Record 16 of Set 5 | norman wells
# 217 arrecife
# Processing Record 17 of Set 5 | arrecife
# 218 laguna
# Processing Record 18 of Set 5 | laguna
# 219 provideniya
# Processing Record 19 of Set 5 | provideniya
# 220 shiraz
# Processing Record 20 of Set 5 | shiraz
# 221 te anau
# Processing Record 21 of Set 5 | te anau
# 222 saleaula
# Processing Record 22 of Set 5 | saleaula
# City not found. Skipping...
# 223 port-de-bouc
# Processing Record 23 of Set 5 | port-de-bouc
# 224 acarau
# Processing Record 24 of Set 5 | acarau
# 225 ostrovnoy
# Processing Record 25 of Set 5 | ostrovnoy
# 226 najran
# Processing Record 26 of Set 5 | najran
# 227 hithadhoo
# Processing Record 27 of Set 5 | hithadhoo
# 228 butaritari
# Processing Record 28 of Set 5 | butaritari
# 229 quatre cocos
# Processing Record 29 of Set 5 | quatre cocos
# 230 geraldton
# Processing Record 30 of Set 5 | geraldton
# 231 tynset
# Processing Record 31 of Set 5 | tynset
# 232 vardo
# Processing Record 32 of Set 5 | vardo
# 233 tromso
# Processing Record 33 of Set 5 | tromso
# 234 kyzyl-suu
# Processing Record 34 of Set 5 | kyzyl-suu
# 235 vila franca do campo
# Processing Record 35 of Set 5 | vila franca do campo
# 236 egvekinot
# Processing Record 36 of Set 5 | egvekinot
# 237 grand river south east
# Processing Record 37 of Set 5 | grand river south east
# City not found. Skipping...
# 238 moree
# Processing Record 38 of Set 5 | moree
# 239 ceres
# Processing Record 39 of Set 5 | ceres
# 240 puerto ayora
# Processing Record 40 of Set 5 | puerto ayora
# 241 shimoda
# Processing Record 41 of Set 5 | shimoda
# 242 dobrinka
# Processing Record 42 of Set 5 | dobrinka
# 243 caravelas
# Processing Record 43 of Set 5 | caravelas
# 244 gouloure
# Processing Record 44 of Set 5 | gouloure
# 245 rawannawi
# Processing Record 45 of Set 5 | rawannawi
# City not found. Skipping...
# 246 lagoa
# Processing Record 46 of Set 5 | lagoa
# 247 ambagarh chauki
# Processing Record 47 of Set 5 | ambagarh chauki
# 248 hattiesburg
# Processing Record 48 of Set 5 | hattiesburg
# 249 kapaa
# Processing Record 49 of Set 5 | kapaa
# 250 itarema
# Processing Record 0 of Set 6 | itarema
# 251 ketchikan
# Processing Record 1 of Set 6 | ketchikan
# 252 oshnaviyeh
# Processing Record 2 of Set 6 | oshnaviyeh
# 253 noyabrsk
# Processing Record 3 of Set 6 | noyabrsk
# 254 channel-port aux basques
# Processing Record 4 of Set 6 | channel-port aux basques
# 255 mackay
# Processing Record 5 of Set 6 | mackay
# 256 byron bay
# Processing Record 6 of Set 6 | byron bay
# 257 sasykoli
# Processing Record 7 of Set 6 | sasykoli
# 258 belyy yar
# Processing Record 8 of Set 6 | belyy yar
# 259 axim
# Processing Record 9 of Set 6 | axim
# 260 paysandu
# Processing Record 10 of Set 6 | paysandu
# 261 guanay
# Processing Record 11 of Set 6 | guanay
# 262 tigil
# Processing Record 12 of Set 6 | tigil
# 263 aksu
# Processing Record 13 of Set 6 | aksu
# 264 molo
# Processing Record 14 of Set 6 | molo
# 265 saint-philippe
# Processing Record 15 of Set 6 | saint-philippe
# 266 pemba
# Processing Record 16 of Set 6 | pemba
# 267 progreso
# Processing Record 17 of Set 6 | progreso
# 268 saldanha
# Processing Record 18 of Set 6 | saldanha
# 269 brae
# Processing Record 19 of Set 6 | brae
# 270 sanok
# Processing Record 20 of Set 6 | sanok
# 271 montes altos
# Processing Record 21 of Set 6 | montes altos
# 272 pangnirtung
# Processing Record 22 of Set 6 | pangnirtung
# 273 atlantic city
# Processing Record 23 of Set 6 | atlantic city
# 274 maragogi
# Processing Record 24 of Set 6 | maragogi
# 275 avera
# Processing Record 25 of Set 6 | avera
# 276 lichinga
# Processing Record 26 of Set 6 | lichinga
# 277 souillac
# Processing Record 27 of Set 6 | souillac
# 278 sao felix do xingu
# Processing Record 28 of Set 6 | sao felix do xingu
# 279 uthal
# Processing Record 29 of Set 6 | uthal
# 280 wairoa
# Processing Record 30 of Set 6 | wairoa
# 281 bonavista
# Processing Record 31 of Set 6 | bonavista
# 282 alyangula
# Processing Record 32 of Set 6 | alyangula
# 283 arlit
# Processing Record 33 of Set 6 | arlit
# 284 los llanos de aridane
# Processing Record 34 of Set 6 | los llanos de aridane
# 285 padang
# Processing Record 35 of Set 6 | padang
# 286 komsomolskiy
# Processing Record 36 of Set 6 | komsomolskiy
# 287 tres lagoas
# Processing Record 37 of Set 6 | tres lagoas
# 288 sao joao da barra
# Processing Record 38 of Set 6 | sao joao da barra
# 289 mayo
# Processing Record 39 of Set 6 | mayo
# 290 grindavik
# Processing Record 40 of Set 6 | grindavik
# 291 vila velha
# Processing Record 41 of Set 6 | vila velha
# 292 barentsburg
# Processing Record 42 of Set 6 | barentsburg
# City not found. Skipping...
# 293 suntar
# Processing Record 43 of Set 6 | suntar
# 294 aberdeen
# Processing Record 44 of Set 6 | aberdeen
# 295 ahipara
# Processing Record 45 of Set 6 | ahipara
# 296 ornskoldsvik
# Processing Record 46 of Set 6 | ornskoldsvik
# 297 ust-kamchatsk
# Processing Record 47 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# 298 benidorm
# Processing Record 48 of Set 6 | benidorm
# 299 nachalovo
# Processing Record 49 of Set 6 | nachalovo
# 300 ialibu
# Processing Record 0 of Set 7 | ialibu
# 301 codrington
# Processing Record 1 of Set 7 | codrington
# 302 kroya
# Processing Record 2 of Set 7 | kroya
# 303 havre-saint-pierre
# Processing Record 3 of Set 7 | havre-saint-pierre
# 304 andenes
# Processing Record 4 of Set 7 | andenes
# 305 carahue
# Processing Record 5 of Set 7 | carahue
# 306 jalingo
# Processing Record 6 of Set 7 | jalingo
# 307 sorvag
# Processing Record 7 of Set 7 | sorvag
# City not found. Skipping...
# 308 mitu
# Processing Record 8 of Set 7 | mitu
# 309 auki
# Processing Record 9 of Set 7 | auki
# 310 palana
# Processing Record 10 of Set 7 | palana
# 311 birao
# Processing Record 11 of Set 7 | birao
# 312 phalodi
# Processing Record 12 of Set 7 | phalodi
# 313 saint-georges
# Processing Record 13 of Set 7 | saint-georges
# 314 pevek
# Processing Record 14 of Set 7 | pevek
# 315 lodwar
# Processing Record 15 of Set 7 | lodwar
# 316 qasigiannguit
# Processing Record 16 of Set 7 | qasigiannguit
# 317 donegal
# Processing Record 17 of Set 7 | donegal
# 318 airai
# Processing Record 18 of Set 7 | airai
# 319 la ronge
# Processing Record 19 of Set 7 | la ronge
# 320 severo-yeniseyskiy
# Processing Record 20 of Set 7 | severo-yeniseyskiy
# 321 myitkyina
# Processing Record 21 of Set 7 | myitkyina
# 322 datong
# Processing Record 22 of Set 7 | datong
# 323 damietta
# Processing Record 23 of Set 7 | damietta
# 324 matara
# Processing Record 24 of Set 7 | matara
# 325 san felipe
# Processing Record 25 of Set 7 | san felipe
# 326 portland
# Processing Record 26 of Set 7 | portland
# 327 hinesburg
# Processing Record 27 of Set 7 | hinesburg
# 328 gdov
# Processing Record 28 of Set 7 | gdov
# 329 kulhudhuffushi
# Processing Record 29 of Set 7 | kulhudhuffushi
# 330 mahon
# Processing Record 30 of Set 7 | mahon
# 331 srednekolymsk
# Processing Record 31 of Set 7 | srednekolymsk
# 332 torbay
# Processing Record 32 of Set 7 | torbay
# 333 palabuhanratu
# Processing Record 33 of Set 7 | palabuhanratu
# City not found. Skipping...
# 334 buraydah
# Processing Record 34 of Set 7 | buraydah
# 335 jertih
# Processing Record 35 of Set 7 | jertih
# 336 poum
# Processing Record 36 of Set 7 | poum
# 337 carnot
# Processing Record 37 of Set 7 | carnot
# 338 rosarito
# Processing Record 38 of Set 7 | rosarito
# 339 karaton
# Processing Record 39 of Set 7 | karaton
# 340 cidreira
# Processing Record 40 of Set 7 | cidreira
# 341 menongue
# Processing Record 41 of Set 7 | menongue
# 342 vallenar
# Processing Record 42 of Set 7 | vallenar
# 343 ponta delgada
# Processing Record 43 of Set 7 | ponta delgada
# 344 antofagasta
# Processing Record 44 of Set 7 | antofagasta
# 345 champerico
# Processing Record 45 of Set 7 | champerico
# 346 kuminskiy
# Processing Record 46 of Set 7 | kuminskiy
# 347 kaoma
# Processing Record 47 of Set 7 | kaoma
# 348 libreville
# Processing Record 48 of Set 7 | libreville
# 349 lazaro cardenas
# Processing Record 49 of Set 7 | lazaro cardenas
# 350 baherden
# Processing Record 0 of Set 8 | baherden
# 351 bull savanna
# Processing Record 1 of Set 8 | bull savanna
# 352 devils lake
# Processing Record 2 of Set 8 | devils lake
# 353 zambezi
# Processing Record 3 of Set 8 | zambezi
# 354 sinnamary
# Processing Record 4 of Set 8 | sinnamary
# 355 hofn
# Processing Record 5 of Set 8 | hofn
# 356 longyearbyen
# Processing Record 6 of Set 8 | longyearbyen
# 357 moose factory
# Processing Record 7 of Set 8 | moose factory
# 358 taburi
# Processing Record 8 of Set 8 | taburi
# City not found. Skipping...
# 359 luang prabang
# Processing Record 9 of Set 8 | luang prabang
# 360 derzhavinsk
# Processing Record 10 of Set 8 | derzhavinsk
# 361 chuy
# Processing Record 11 of Set 8 | chuy
# 362 khiv
# Processing Record 12 of Set 8 | khiv
# 363 rundu
# Processing Record 13 of Set 8 | rundu
# 364 mpraeso
# Processing Record 14 of Set 8 | mpraeso
# 365 paradwip
# Processing Record 15 of Set 8 | paradwip
# City not found. Skipping...
# 366 gurskoye
# Processing Record 16 of Set 8 | gurskoye
# City not found. Skipping...
# 367 moulins
# Processing Record 17 of Set 8 | moulins
# 368 iralaya
# Processing Record 18 of Set 8 | iralaya
# 369 igrim
# Processing Record 19 of Set 8 | igrim
# 370 kawalu
# Processing Record 20 of Set 8 | kawalu
# 371 bathsheba
# Processing Record 21 of Set 8 | bathsheba
# 372 diamantina
# Processing Record 22 of Set 8 | diamantina
# 373 warqla
# Processing Record 23 of Set 8 | warqla
# City not found. Skipping...
# 374 gusau
# Processing Record 24 of Set 8 | gusau
# 375 ende
# Processing Record 25 of Set 8 | ende
# 376 umm lajj
# Processing Record 26 of Set 8 | umm lajj
# 377 yarim
# Processing Record 27 of Set 8 | yarim
# 378 tarrega
# Processing Record 28 of Set 8 | tarrega
# 379 mogadishu
# Processing Record 29 of Set 8 | mogadishu
# 380 vredendal
# Processing Record 30 of Set 8 | vredendal
# 381 pokaran
# Processing Record 31 of Set 8 | pokaran
# 382 toliary
# Processing Record 32 of Set 8 | toliary
# City not found. Skipping...
# 383 hamilton
# Processing Record 33 of Set 8 | hamilton
# 384 shahr-e babak
# Processing Record 34 of Set 8 | shahr-e babak
# 385 roma
# Processing Record 35 of Set 8 | roma
# 386 samusu
# Processing Record 36 of Set 8 | samusu
# City not found. Skipping...
# 387 negombo
# Processing Record 37 of Set 8 | negombo
# 388 harjavalta
# Processing Record 38 of Set 8 | harjavalta
# 389 yarmouth
# Processing Record 39 of Set 8 | yarmouth
# 390 faya
# Processing Record 40 of Set 8 | faya
# 391 maceio
# Processing Record 41 of Set 8 | maceio
# 392 attawapiskat
# Processing Record 42 of Set 8 | attawapiskat
# City not found. Skipping...
# 393 tessalit
# Processing Record 43 of Set 8 | tessalit
# 394 oum hadjer
# Processing Record 44 of Set 8 | oum hadjer
# 395 svetlaya
# Processing Record 45 of Set 8 | svetlaya
# 396 hede
# Processing Record 46 of Set 8 | hede
# 397 boulsa
# Processing Record 47 of Set 8 | boulsa
# 398 alabino
# Processing Record 48 of Set 8 | alabino
# 399 frankfort
# Processing Record 49 of Set 8 | frankfort
# 400 bac ninh
# Processing Record 0 of Set 9 | bac ninh
# 401 kumluca
# Processing Record 1 of Set 9 | kumluca
# 402 jumla
# Processing Record 2 of Set 9 | jumla
# 403 husavik
# Processing Record 3 of Set 9 | husavik
# 404 honiara
# Processing Record 4 of Set 9 | honiara
# 405 conceicao do araguaia
# Processing Record 5 of Set 9 | conceicao do araguaia
# 406 port-de-paix
# Processing Record 6 of Set 9 | port-de-paix
# City not found. Skipping...
# 407 guapore
# Processing Record 7 of Set 9 | guapore
# 408 san jeronimo
# Processing Record 8 of Set 9 | san jeronimo
# 409 samarai
# Processing Record 9 of Set 9 | samarai
# 410 tooele
# Processing Record 10 of Set 9 | tooele
# 411 yatou
# Processing Record 11 of Set 9 | yatou
# 412 lakatoro
# Processing Record 12 of Set 9 | lakatoro
# 413 nouakchott
# Processing Record 13 of Set 9 | nouakchott
# 414 luderitz
# Processing Record 14 of Set 9 | luderitz
# 415 yaring
# Processing Record 15 of Set 9 | yaring
# 416 nemuro
# Processing Record 16 of Set 9 | nemuro
# 417 kintinku
# Processing Record 17 of Set 9 | kintinku
# 418 salekhard
# Processing Record 18 of Set 9 | salekhard
# 419 christchurch
# Processing Record 19 of Set 9 | christchurch
# 420 hasaki
# Processing Record 20 of Set 9 | hasaki
# 421 bargal
# Processing Record 21 of Set 9 | bargal
# City not found. Skipping...
# 422 tabuk
# Processing Record 22 of Set 9 | tabuk
# 423 lasa
# Processing Record 23 of Set 9 | lasa
# 424 kuruksay
# Processing Record 24 of Set 9 | kuruksay
# City not found. Skipping...
# 425 marcona
# Processing Record 25 of Set 9 | marcona
# City not found. Skipping...
# 426 sao domingos
# Processing Record 26 of Set 9 | sao domingos
# 427 kahului
# Processing Record 27 of Set 9 | kahului
# 428 elko
# Processing Record 28 of Set 9 | elko
# 429 umzimvubu
# Processing Record 29 of Set 9 | umzimvubu
# City not found. Skipping...
# 430 san luis
# Processing Record 30 of Set 9 | san luis
# 431 labutta
# Processing Record 31 of Set 9 | labutta
# City not found. Skipping...
# 432 fare
# Processing Record 32 of Set 9 | fare
# 433 belmonte
# Processing Record 33 of Set 9 | belmonte
# 434 arenzano
# Processing Record 34 of Set 9 | arenzano
# 435 jinka
# Processing Record 35 of Set 9 | jinka
# 436 zhuanghe
# Processing Record 36 of Set 9 | zhuanghe
# 437 lata
# Processing Record 37 of Set 9 | lata
# 438 meridian
# Processing Record 38 of Set 9 | meridian
# 439 douglas
# Processing Record 39 of Set 9 | douglas
# 440 sur
# Processing Record 40 of Set 9 | sur
# 441 koraput
# Processing Record 41 of Set 9 | koraput
# 442 saskylakh
# Processing Record 42 of Set 9 | saskylakh
# 443 copiapo
# Processing Record 43 of Set 9 | copiapo
# 444 port keats
# Processing Record 44 of Set 9 | port keats
# 445 dakoro
# Processing Record 45 of Set 9 | dakoro
# 446 maumere
# Processing Record 46 of Set 9 | maumere
# 447 kouroussa
# Processing Record 47 of Set 9 | kouroussa
# 448 arklow
# Processing Record 48 of Set 9 | arklow
# 449 tura
# Processing Record 49 of Set 9 | tura
# 450 marovoay
# Processing Record 0 of Set 10 | marovoay
# 451 karpogory
# Processing Record 1 of Set 10 | karpogory
# 452 barcelos
# Processing Record 2 of Set 10 | barcelos
# 453 eenhana
# Processing Record 3 of Set 10 | eenhana
# 454 chabahar
# Processing Record 4 of Set 10 | chabahar
# 455 labuhan
# Processing Record 5 of Set 10 | labuhan
# 456 juneau
# Processing Record 6 of Set 10 | juneau
# 457 louisbourg
# Processing Record 7 of Set 10 | louisbourg
# City not found. Skipping...
# 458 olen
# Processing Record 8 of Set 10 | olen
# 459 mizdah
# Processing Record 9 of Set 10 | mizdah
# 460 dingle
# Processing Record 10 of Set 10 | dingle
# 461 vao
# Processing Record 11 of Set 10 | vao
# 462 port-gentil
# Processing Record 12 of Set 10 | port-gentil
# 463 bogorodskoye
# Processing Record 13 of Set 10 | bogorodskoye
# 464 krasnyy yar
# Processing Record 14 of Set 10 | krasnyy yar
# 465 casper
# Processing Record 15 of Set 10 | casper
# 466 coquimbo
# Processing Record 16 of Set 10 | coquimbo
# 467 paluan
# Processing Record 17 of Set 10 | paluan
# 468 kavaratti
# Processing Record 18 of Set 10 | kavaratti
# 469 aparecida
# Processing Record 19 of Set 10 | aparecida
# 470 russell
# Processing Record 20 of Set 10 | russell
# 471 sao filipe
# Processing Record 21 of Set 10 | sao filipe
# 472 tuy hoa
# Processing Record 22 of Set 10 | tuy hoa
# 473 apucarana
# Processing Record 23 of Set 10 | apucarana
# 474 le havre
# Processing Record 24 of Set 10 | le havre
# 475 kobe
# Processing Record 25 of Set 10 | kobe
# 476 qeshm
# Processing Record 26 of Set 10 | qeshm
# 477 iskateley
# Processing Record 27 of Set 10 | iskateley
# 478 katima mulilo
# Processing Record 28 of Set 10 | katima mulilo
# 479 zunyi
# Processing Record 29 of Set 10 | zunyi
# 480 dalby
# Processing Record 30 of Set 10 | dalby
# 481 tralee
# Processing Record 31 of Set 10 | tralee
# 482 namtsy
# Processing Record 32 of Set 10 | namtsy
# 483 mount gambier
# Processing Record 33 of Set 10 | mount gambier
# 484 zhigansk
# Processing Record 34 of Set 10 | zhigansk
# 485 balkanabat
# Processing Record 35 of Set 10 | balkanabat
# 486 jizan
# Processing Record 36 of Set 10 | jizan
# 487 grafton
# Processing Record 37 of Set 10 | grafton
# 488 bandarbeyla
# Processing Record 38 of Set 10 | bandarbeyla
# 489 noumea
# Processing Record 39 of Set 10 | noumea
# 490 nyurba
# Processing Record 40 of Set 10 | nyurba
# 491 meulaboh
# Processing Record 41 of Set 10 | meulaboh
# 492 malatya
# Processing Record 42 of Set 10 | malatya
# 493 suzhou
# Processing Record 43 of Set 10 | suzhou
# 494 erbaa
# Processing Record 44 of Set 10 | erbaa
# 495 honningsvag
# Processing Record 45 of Set 10 | honningsvag
# 496 new richmond
# Processing Record 46 of Set 10 | new richmond
# 497 lesozavodsk
# Processing Record 47 of Set 10 | lesozavodsk
# 498 isangel
# Processing Record 48 of Set 10 | isangel
# 499 mariinskiy posad
# Processing Record 49 of Set 10 | mariinskiy posad
# 500 yulara
# Processing Record 0 of Set 11 | yulara
# 501 keta
# Processing Record 1 of Set 11 | keta
# 502 pochutla
# Processing Record 2 of Set 11 | pochutla
# 503 toftir
# Processing Record 3 of Set 11 | toftir
# City not found. Skipping...
# 504 mago
# Processing Record 4 of Set 11 | mago
# 505 inirida
# Processing Record 5 of Set 11 | inirida
# 506 mehamn
# Processing Record 6 of Set 11 | mehamn
# 507 immenstadt
# Processing Record 7 of Set 11 | immenstadt
# 508 podor
# Processing Record 8 of Set 11 | podor
# 509 pingliang
# Processing Record 9 of Set 11 | pingliang
# 510 tottori
# Processing Record 10 of Set 11 | tottori
# 511 jenison
# Processing Record 11 of Set 11 | jenison
# 512 tabou
# Processing Record 12 of Set 11 | tabou
# 513 grand gaube
# Processing Record 13 of Set 11 | grand gaube
# 514 tual
# Processing Record 14 of Set 11 | tual
# 515 yar-sale
# Processing Record 15 of Set 11 | yar-sale
# 516 tlahualilo
# Processing Record 16 of Set 11 | tlahualilo
# City not found. Skipping...
# 517 tuatapere
# Processing Record 17 of Set 11 | tuatapere
# 518 along
# Processing Record 18 of Set 11 | along
# 519 karauzyak
# Processing Record 19 of Set 11 | karauzyak
# City not found. Skipping...
# 520 oranjestad
# Processing Record 20 of Set 11 | oranjestad
# 521 severo-kurilsk
# Processing Record 21 of Set 11 | severo-kurilsk
# 522 horki
# Processing Record 22 of Set 11 | horki
# 523 lewisporte
# Processing Record 23 of Set 11 | lewisporte
# 524 ipixuna
# Processing Record 24 of Set 11 | ipixuna
# 525 labrea
# Processing Record 25 of Set 11 | labrea
# 526 sola
# Processing Record 26 of Set 11 | sola
# 527 neiafu
# Processing Record 27 of Set 11 | neiafu
# 528 dzerzhinsk
# Processing Record 28 of Set 11 | dzerzhinsk
# 529 punta alta
# Processing Record 29 of Set 11 | punta alta
# 530 carndonagh
# Processing Record 30 of Set 11 | carndonagh
# 531 cockburn town
# Processing Record 31 of Set 11 | cockburn town
# 532 kununurra
# Processing Record 32 of Set 11 | kununurra
# 533 aniva
# Processing Record 33 of Set 11 | aniva
# 534 college
# Processing Record 34 of Set 11 | college
# 535 nalut
# Processing Record 35 of Set 11 | nalut
# 536 sherlovaya gora
# Processing Record 36 of Set 11 | sherlovaya gora
# 537 imbituba
# Processing Record 37 of Set 11 | imbituba
# 538 wapi pathum
# Processing Record 38 of Set 11 | wapi pathum
# 539 creel
# Processing Record 39 of Set 11 | creel
# 540 vagur
# Processing Record 40 of Set 11 | vagur
# 541 hobyo
# Processing Record 41 of Set 11 | hobyo
# 542 bundibugyo
# Processing Record 42 of Set 11 | bundibugyo
# 543 bontang
# Processing Record 43 of Set 11 | bontang
# 544 cayenne
# Processing Record 44 of Set 11 | cayenne
# 545 tiksi
# Processing Record 45 of Set 11 | tiksi
# 546 nogliki
# Processing Record 46 of Set 11 | nogliki
# 547 deputatskiy
# Processing Record 47 of Set 11 | deputatskiy
# 548 hervey bay
# Processing Record 48 of Set 11 | hervey bay
# 549 malindi
# Processing Record 49 of Set 11 | malindi
# 550 aktash
# Processing Record 0 of Set 12 | aktash
# 551 pombal
# Processing Record 1 of Set 12 | pombal
# 552 terra santa
# Processing Record 2 of Set 12 | terra santa
# 553 coihaique
# Processing Record 3 of Set 12 | coihaique
# 554 zyryanka
# Processing Record 4 of Set 12 | zyryanka
# 555 gospic
# Processing Record 5 of Set 12 | gospic
# 556 springbok
# Processing Record 6 of Set 12 | springbok
# 557 hami
# Processing Record 7 of Set 12 | hami
# 558 jiuquan
# Processing Record 8 of Set 12 | jiuquan
# 559 beloye
# Processing Record 9 of Set 12 | beloye
# 560 valleyview
# Processing Record 10 of Set 12 | valleyview
# 561 jasper
# Processing Record 11 of Set 12 | jasper
# 562 campbell river
# Processing Record 12 of Set 12 | campbell river
# 563 bushenyi
# Processing Record 13 of Set 12 | bushenyi
# 564 maridi
# Processing Record 14 of Set 12 | maridi
# 565 dhidhdhoo
# Processing Record 15 of Set 12 | dhidhdhoo
# 566 dagana
# Processing Record 16 of Set 12 | dagana
# 567 ape
# Processing Record 17 of Set 12 | ape
# 568 houma
# Processing Record 18 of Set 12 | houma
# 569 san lorenzo
# Processing Record 19 of Set 12 | san lorenzo
# 570 waipawa
# Processing Record 20 of Set 12 | waipawa
# 571 mentok
# Processing Record 21 of Set 12 | mentok
# City not found. Skipping...
# 572 chimbote
# Processing Record 22 of Set 12 | chimbote
# 573 fenoarivo
# Processing Record 23 of Set 12 | fenoarivo
# 574 sumbe
# Processing Record 24 of Set 12 | sumbe
# 575 san patricio
# Processing Record 25 of Set 12 | san patricio
# 576 las vegas
# Processing Record 26 of Set 12 | las vegas
# 577 broome
# Processing Record 27 of Set 12 | broome
# 578 madimba
# Processing Record 28 of Set 12 | madimba
# 579 esperance
# Processing Record 29 of Set 12 | esperance
# 580 nuuk
# Processing Record 30 of Set 12 | nuuk
# 581 jacmel
# Processing Record 31 of Set 12 | jacmel
# 582 churapcha
# Processing Record 32 of Set 12 | churapcha
# 583 pangody
# Processing Record 33 of Set 12 | pangody
# 584 muros
# Processing Record 34 of Set 12 | muros
# 585 ayorou
# Processing Record 35 of Set 12 | ayorou
# 586 caucaia
# Processing Record 36 of Set 12 | caucaia
# 587 montrose
# Processing Record 37 of Set 12 | montrose
# 588 palasa
# Processing Record 38 of Set 12 | palasa
# 589 beidao
# Processing Record 39 of Set 12 | beidao
# 590 ciudad bolivar
# Processing Record 40 of Set 12 | ciudad bolivar
# 591 ust-nera
# Processing Record 41 of Set 12 | ust-nera
# 592 norrtalje
# Processing Record 42 of Set 12 | norrtalje
# 593 conde
# Processing Record 43 of Set 12 | conde
# 594 grand centre
# Processing Record 44 of Set 12 | grand centre
# City not found. Skipping...
# 595 ondjiva
# Processing Record 45 of Set 12 | ondjiva
# 596 puerto leguizamo
# Processing Record 46 of Set 12 | puerto leguizamo
# 597 laiwu
# Processing Record 47 of Set 12 | laiwu
# 598 bafata
# Processing Record 48 of Set 12 | bafata
# 599 pacatuba
# Processing Record 49 of Set 12 | pacatuba
# 600 shingu
# Processing Record 0 of Set 13 | shingu
# 601 cabra
# Processing Record 1 of Set 13 | cabra
# 602 allapalli
# Processing Record 2 of Set 13 | allapalli
# 603 yuzhno-yeniseyskiy
# Processing Record 3 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# 604 kalmunai
# Processing Record 4 of Set 13 | kalmunai
# 605 cape coast
# Processing Record 5 of Set 13 | cape coast
# 606 ambodifototra
# Processing Record 6 of Set 13 | ambodifototra
# City not found. Skipping...
# 607 tolaga bay
# Processing Record 7 of Set 13 | tolaga bay
# 608 changji
# Processing Record 8 of Set 13 | changji
# 609 petatlan
# Processing Record 9 of Set 13 | petatlan
# 610 flin flon
# Processing Record 10 of Set 13 | flin flon
# 611 omboue
# Processing Record 11 of Set 13 | omboue
# 612 puerto escondido
# Processing Record 12 of Set 13 | puerto escondido
# 613 krasnoyarsk-66
# Processing Record 13 of Set 13 | krasnoyarsk-66
# City not found. Skipping...
# 614 rio cuarto
# Processing Record 14 of Set 13 | rio cuarto
# 615 kysyl-syr
# Processing Record 15 of Set 13 | kysyl-syr
# 616 esso
# Processing Record 16 of Set 13 | esso
# 617 atbasar
# Processing Record 17 of Set 13 | atbasar
# 618 port macquarie
# Processing Record 18 of Set 13 | port macquarie
# 619 abeche
# Processing Record 19 of Set 13 | abeche
# 620 ziro
# Processing Record 20 of Set 13 | ziro
# 621 sao jose da coroa grande
# Processing Record 21 of Set 13 | sao jose da coroa grande
# 622 tanout
# Processing Record 22 of Set 13 | tanout
# 623 kosonsoy
# Processing Record 23 of Set 13 | kosonsoy
# 624 pitkyaranta
# Processing Record 24 of Set 13 | pitkyaranta
# 625 salta
# Processing Record 25 of Set 13 | salta
# 626 maxixe
# Processing Record 26 of Set 13 | maxixe
# 627 sioux lookout
# Processing Record 27 of Set 13 | sioux lookout
# 628 ancud
# Processing Record 28 of Set 13 | ancud
# 629 lashio
# Processing Record 29 of Set 13 | lashio
# 630 loikaw
# Processing Record 30 of Set 13 | loikaw
# 631 port hawkesbury
# Processing Record 31 of Set 13 | port hawkesbury
# 632 yuli
# Processing Record 32 of Set 13 | yuli
# 633 chaman
# Processing Record 33 of Set 13 | chaman
# 634 sulangan
# Processing Record 34 of Set 13 | sulangan
# 635 the pas
# Processing Record 35 of Set 13 | the pas
# 636 garden city
# Processing Record 36 of Set 13 | garden city
# 637 richards bay
# Processing Record 37 of Set 13 | richards bay
# 638 kushima
# Processing Record 38 of Set 13 | kushima
# 639 pringsewu
# Processing Record 39 of Set 13 | pringsewu
# 640 meyungs
# Processing Record 40 of Set 13 | meyungs
# City not found. Skipping...
# 641 hermiston
# Processing Record 41 of Set 13 | hermiston
# 642 abbeville
# Processing Record 42 of Set 13 | abbeville
# 643 little current
# Processing Record 43 of Set 13 | little current

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(city_loc)
city_df.head()
# Out:
#           City Country        Date  Longitude  Latitude  Max Temperature  \
# 0      fortuna      US  1584837313    -124.16     40.60            57.99
# 1      ushuaia      AR  1584837313     -68.30    -54.80            41.00
# 2         yako      BF  1584837313      -2.27     12.97            82.42
# 3      mataura      NZ  1584837313     168.86    -46.19            55.99
# 4  new norfolk      AU  1584837313     147.06    -42.78            57.00
#
#    Humidity  Cloudiness  Wind speed
# 0        82           1       12.75
# 1        86          40       17.22
# 2        28          31        5.01
# 3        74          47       18.99
# 4        71          75       14.99

# %%
# Extract relevant fields from the data frame
lats = city_df["Latitude"]
max_temps = city_df["Max Temperature"]
humidity = city_df["Humidity"]
cloudiness = city_df["Cloudiness"]
wind_speed = city_df["Wind speed"]

# %%
# Export the City_Data into a csv
city_df.to_csv(output_data_file, index_label="City_ID")
# Show Record Count
city_df.count()
# Out:
# City               596
# Country            596
# Date               596
# Longitude          596
# Latitude           596
# Max Temperature    596
# Humidity           596
# Cloudiness         596
# Wind speed         596
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lats, max_temps, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75)
plt.grid()
plt.title("Max Temperature v Latitude")
plt.xlabel("Max Temperature (Farenheit)")
plt.ylabel("Latitude")
plt.savefig("output_data/fig1.png")
print("This scatter plot shows the relationship between the maximum temperature and latitude")
# Out:
# This scatter plot shows the relationship between the maximum temperature and latitude

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lats,humidity, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75)
plt.title("Latitude v Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
plt.savefig("output_data/fig2.png")
print("This scatter plot shows the relationship between the latitude and humidity")
# Out:
# This scatter plot shows the relationship between the latitude and humidity

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lats, cloudiness, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75)
plt.title("Latitude v Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.savefig("output_data/fig3.png")
print("This scatter plot shows the relationship between the latitude and cloudliness")
# Out:
# This scatter plot shows the relationship between the latitude and cloudliness

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(lats,wind_speed, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75)
plt.title("latitude vs. wind speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
plt.savefig("output_data/fig4.png")
print("This scatter plot shows the relationship between the latitude and wind speed")
# Out:
# This scatter plot shows the relationship between the latitude and wind speed

# %% [markdown]
# ## Linear Regression

# %%
city_df
# Out:
#                City Country        Date  Longitude  Latitude  Max Temperature  \
# 0           fortuna      US  1584837313    -124.16     40.60            57.99
# 1           ushuaia      AR  1584837313     -68.30    -54.80            41.00
# 2              yako      BF  1584837313      -2.27     12.97            82.42
# 3           mataura      NZ  1584837313     168.86    -46.19            55.99
# 4       new norfolk      AU  1584837313     147.06    -42.78            57.00
# ..              ...     ...         ...        ...       ...              ...
# 591         kushima      JP  1584837397     131.23     31.46            62.60
# 592       pringsewu      ID  1584837397     104.97     -5.36            72.52
# 593       hermiston      US  1584837195    -119.29     45.84            68.00
# 594       abbeville      FR  1584837098       1.83     50.10            41.00
# 595  little current      CA  1584837397     -81.92     45.98            23.00
#
#      Humidity  Cloudiness  Wind speed
# 0          82           1       12.75
# 1          86          40       17.22
# 2          28          31        5.01
# 3          74          47       18.99
# 4          71          75       14.99
# ..        ...         ...         ...
# 591        77          75        1.12
# 592        96          66        1.95
# 593        22           1        3.36
# 594        65          42       13.87
# 595        57           1        8.05
#
# [596 rows x 9 columns]

# %%
# OPTIONAL: Create a function to create Linear Regression plots
nothern = city_df.loc[city_df["Latitude"] >= 0.0, :]
nothern.reset_index(inplace=True)

southern = city_df.loc[city_df["Latitude"] < 0.0, :]
southern.reset_index(inplace=True)

# %%
nothern.describe()
# Out:
#             index          Date   Longitude    Latitude  Max Temperature  \
# count  409.000000  4.090000e+02  409.000000  409.000000       409.000000
# mean   304.540342  1.584837e+09   14.115917   37.688411        48.754352
# std    169.737063  7.245789e+01   85.750320   20.452604        26.471978
# min      0.000000  1.584837e+09 -179.170000    0.130000       -16.040000
# 25%    157.000000  1.584837e+09  -64.620000   18.770000        30.760000
# 50%    306.000000  1.584837e+09   18.700000   39.050000        51.010000
# 75%    452.000000  1.584837e+09   81.820000   54.770000        73.400000
# max    595.000000  1.584837e+09  179.320000   78.220000        91.400000
#
#          Humidity  Cloudiness  Wind speed
# count  409.000000  409.000000  409.000000
# mean    69.061125   48.621027    8.982347
# std     21.325068   37.644371    7.008908
# min      8.000000    0.000000    0.380000
# 25%     57.000000   11.000000    4.050000
# 50%     74.000000   40.000000    7.070000
# 75%     86.000000   86.000000   12.060000
# max    100.000000  100.000000   53.020000

# %%
southern.describe()
# Out:
#             index          Date   Longitude    Latitude  Max Temperature  \
# count  187.000000  1.870000e+02  187.000000  187.000000       187.000000
# mean   282.101604  1.584837e+09   32.859198  -20.826684        72.431230
# std    176.935975  7.106463e+01   95.791182   13.203686         9.744849
# min      1.000000  1.584837e+09 -175.200000  -54.800000        41.000000
# 25%    128.000000  1.584837e+09  -51.785000  -31.995000        66.210000
# 50%    267.000000  1.584837e+09   25.570000  -20.330000        75.040000
# 75%    428.500000  1.584837e+09  130.270000   -8.970000        79.540000
# max    592.000000  1.584837e+09  178.300000   -0.190000        89.600000
#
#          Humidity  Cloudiness  Wind speed
# count  187.000000  187.000000  187.000000
# mean    76.245989   49.208556    8.134064
# std     16.192505   36.123806    5.393036
# min      7.000000    0.000000    0.540000
# 25%     69.000000   18.500000    3.890000
# 50%     78.000000   43.000000    6.930000
# 75%     88.000000   82.000000   11.410000
# max    100.000000  100.000000   25.280000

# %%
# Create Northern and Southern Hemisphere DataFrames
def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    plt.savefig(f"output_data/{ifig}.png")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Nx_axis = nothern['Latitude'] 
Ny_axis = nothern['Max Temperature']   
xlbl = "Latitude" 
ylbl = "Max Temp" 
lblpos = (0,25)
ifig = 'N_MaxTemp_vs_Lat' 
plotLinearRegression(Nx_axis, Ny_axis,xlbl,ylbl,lblpos,ifig)
# Out:
# The r-squared is: -0.9027612110221376

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Sx_axis = southern['Latitude'] 
Sy_axis = southern['Max Temperature']   
xlbl = "Latitude" 
ylbl = "Max Temp" 
lblpos = (0,25) 
ifig = 'N_MaxTemp_vs_Lat' 
plotLinearRegression(Sx_axis, Sy_axis,xlbl,ylbl,lblpos,ifig)
# Out:
# The r-squared is: 0.5040491605760246

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Nx_axis = nothern['Latitude'] 
Ny_axis = nothern['Humidity']   
xlbl = "Latitude" 
ylbl = "Humididty" 
lblpos = (0,25) 
ifig = 'N_Humidity_vs_Lat' 
plotLinearRegression(Nx_axis, Ny_axis,xlbl,ylbl,lblpos,ifig)
# Out:
# The r-squared is: 0.22420887853393978

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Sx_axis = nothern['Latitude'] 
Sy_axis = nothern['Humidity']   
xlbl = "Latitude" 
ylbl = "Humididty" 
lblpos = (0,25) 
ifig = 'N__Humidity vs_Lat' 
plotLinearRegression(Sx_axis, Sy_axis,xlbl,ylbl,lblpos,ifig)
# Out:
# The r-squared is: 0.22420887853393978

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Nx_axis = nothern['Latitude'] 
Ny_axis = nothern['Cloudiness']   
xlbl = "Latitude" 
ylbl = "Cloudiness" 
lblpos = (0,25) 
ifig = 'N_Cloudiness_vs_Lat' 
plotLinearRegression(Nx_axis, Ny_axis,xlbl,ylbl,lblpos,ifig)
# Out:
# The r-squared is: 0.22720800931476845

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Sx_axis = nothern['Latitude'] 
Sy_axis = nothern['Cloudiness']   
xlbl = "Latitude" 
ylbl = "Cloudiness" 
lblpos = (0,25) 
ifig = 'S_Cloudiness_vs_Lat' 
plotLinearRegression(Sx_axis, Sy_axis,xlbl,ylbl,lblpos,ifig)
# Out:
# The r-squared is: 0.22720800931476845

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Nx_axis = nothern['Latitude'] 
Ny_axis = nothern['Wind speed']   
xlbl = "Latitude" 
ylbl = "Wind speed" 
lblpos = (0,25) 
ifig = 'N_Wind_speed_vs_Lat' 
plotLinearRegression(Nx_axis, Ny_axis,xlbl,ylbl,lblpos,ifig)
# Out:
# The r-squared is: 0.20539871001456253

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Sx_axis = southern['Latitude'] 
Sy_axis = southern['Wind speed']   
xlbl = "Latitude" 
ylbl = "Wind speed" 
lblpos = (0,25) 
ifig = 'S_Wind_speed_vs_Lat' 
plotLinearRegression(Sx_axis, Sy_axis,xlbl,ylbl,lblpos,ifig)
# Out:
# The r-squared is: -0.5076738680186011
