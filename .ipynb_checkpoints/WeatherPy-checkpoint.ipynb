# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %%
cities
# Out:
# ['carballo',
#  'ushuaia',
#  'padang',
#  'eureka',
#  'taolanaro',
#  'la orilla',
#  'rikitea',
#  'marcona',
#  'geraldton',
#  'chuy',
#  'punta arenas',
#  'kijang',
#  'mar del plata',
#  'rognan',
#  'severo-kurilsk',
#  'kapaa',
#  'nemuro',
#  'juruti',
#  'amderma',
#  'albany',
#  'prince rupert',
#  'nizhneyansk',
#  'qaanaaq',
#  'ruatoria',
#  'bengkulu',
#  'ribeira grande',
#  'jamestown',
#  'saskylakh',
#  'busselton',
#  'la cruz',
#  'atuona',
#  'illoqqortoormiut',
#  'maxixe',
#  'tra vinh',
#  'hobart',
#  'novopokrovka',
#  'huazolotitlan',
#  'butaritari',
#  'lebu',
#  'shetpe',
#  'nome',
#  'kahului',
#  'ponta delgada',
#  'saint andrews',
#  'norman wells',
#  'lata',
#  'marawi',
#  'bilibino',
#  'te anau',
#  'coihaique',
#  'castro',
#  'tiksi',
#  'carnarvon',
#  'peniche',
#  'new norfolk',
#  'hammerfest',
#  'mercedes',
#  'provideniya',
#  'olafsvik',
#  'honiara',
#  'pangkalanbuun',
#  'isangel',
#  'ilulissat',
#  'paysandu',
#  'codrington',
#  'sarankhola',
#  'tasiilaq',
#  'dingle',
#  'ginir',
#  'kieta',
#  'hermanus',
#  'verkhnevilyuysk',
#  'louisbourg',
#  'rong kwang',
#  'saint-louis',
#  'clyde river',
#  'saldanha',
#  'auki',
#  'hilo',
#  'hamilton',
#  'hithadhoo',
#  'kruisfontein',
#  'osorno',
#  'nara',
#  'flin flon',
#  'muros',
#  'xiaoweizhai',
#  'nikolskoye',
#  'tazovskiy',
#  'curup',
#  'yellowknife',
#  'bonavista',
#  'bethel',
#  'bilma',
#  'ust-ishim',
#  'genteng',
#  'wanning',
#  'lompoc',
#  'mahebourg',
#  'yumen',
#  'georgetown',
#  'cape town',
#  'mitsamiouli',
#  'port-gentil',
#  'sovetskiy',
#  'sur',
#  'zunyi',
#  'caravelas',
#  'mehriz',
#  'daru',
#  'mocuba',
#  'rustenburg',
#  'vaini',
#  'boden',
#  'hartselle',
#  'cidreira',
#  'barentsburg',
#  'khash',
#  'namatanai',
#  'itarema',
#  'grand-santi',
#  'port elizabeth',
#  'thompson',
#  'yulara',
#  'touros',
#  'lagoa',
#  'cardenas',
#  'lahaina',
#  'gigmoto',
#  'vostok',
#  'port alfred',
#  'kerema',
#  'zyryanka',
#  'hede',
#  'gushikawa',
#  'tura',
#  'torbay',
#  'avarua',
#  'japura',
#  'la asuncion',
#  'bocas del toro',
#  'port blair',
#  'bac can',
#  'znamenskoye',
#  'puerto ayora',
#  'zhigansk',
#  'tarakan',
#  'ryotsu',
#  'solnechnyy',
#  'tuktoyaktuk',
#  'bluff',
#  'tumannyy',
#  'itoman',
#  'san cristobal',
#  'camacha',
#  'dunedin',
#  'sentyabrskiy',
#  'meyungs',
#  'shache',
#  'arraial do cabo',
#  'umm kaddadah',
#  'stromness',
#  'dikson',
#  'souillac',
#  'chittur',
#  'klaksvik',
#  'galiwinku',
#  'chagda',
#  'san ramon',
#  'avera',
#  'necochea',
#  'saint-pierre',
#  'belushya guba',
#  'ixtapa',
#  'mataura',
#  'kokkola',
#  'khatanga',
#  'ust-kamchatsk',
#  'bubaque',
#  'bredasdorp',
#  'darnah',
#  'barrow',
#  'saint-philippe',
#  'tabiauea',
#  'richards bay',
#  'morehead',
#  'ponta do sol',
#  'leningradskiy',
#  'svetlogorsk',
#  'sayaxche',
#  'kodiak',
#  'punto fijo',
#  'tshikapa',
#  'marystown',
#  'east london',
#  'margate',
#  'samusu',
#  'cap malheureux',
#  'airai',
#  'kuytun',
#  'staryy nadym',
#  'fortuna',
#  'tiznit',
#  'labutta',
#  'agirish',
#  'ust-karsk',
#  'davila',
#  'ola',
#  'altay',
#  'praxedis guerrero',
#  'wolfville',
#  'palmer',
#  'ouadda',
#  'villazon',
#  'belyy yar',
#  'carutapera',
#  'chokurdakh',
#  'krasnovishersk',
#  'chapais',
#  'manado',
#  'kutum',
#  'vila velha',
#  'porto de moz',
#  'jacareacanga',
#  'alexandria',
#  'el alto',
#  'maple creek',
#  'freiberg',
#  'yefira',
#  'shingu',
#  'kavieng',
#  'longyearbyen',
#  'tsihombe',
#  'san andres',
#  'huayang',
#  'hohhot',
#  'bourail',
#  'isfara',
#  'milingimbi',
#  'nanortalik',
#  'soldato-aleksandrovskoye',
#  'ostrovnoy',
#  'dickinson',
#  'sangar',
#  'bozeman',
#  'izhma',
#  'sal rei',
#  'pangody',
#  'mamlyutka',
#  'mount gambier',
#  'mys shmidta',
#  'yakima',
#  'cabo san lucas',
#  'la romana',
#  'xinyu',
#  'le vauclin',
#  'serebryansk',
#  'kabalo',
#  'bargal',
#  'mocajuba',
#  'gambiran',
#  'gamba',
#  'usinsk',
#  'bayan',
#  'sylacauga',
#  'puerto escondido',
#  'mattru',
#  'batagay',
#  'kerrville',
#  'tucupita',
#  'husavik',
#  'eyrarbakki',
#  'katsuura',
#  'lincoln',
#  'pevek',
#  'manicore',
#  'weiser',
#  'tessalit',
#  'belmonte',
#  'selam',
#  'jinchang',
#  'kiama',
#  'kudinovo',
#  'papanasam',
#  'russell',
#  'faya',
#  'ascension',
#  'birpur',
#  'macroom',
#  'ilheus',
#  'abu samrah',
#  'sinnamary',
#  'chifeng',
#  'talnakh',
#  'iqaluit',
#  'kyabram',
#  'male',
#  'joetsu',
#  'vacaria',
#  'kongolo',
#  'khor',
#  'waipawa',
#  'buckeye',
#  'quatre cocos',
#  'teguise',
#  'klyuchi',
#  'mao',
#  'luganville',
#  'sitka',
#  'kamogawa',
#  'najran',
#  'petatlan',
#  'korla',
#  'safwah',
#  'ketchikan',
#  'saint-paul',
#  'grand gaube',
#  'kenai',
#  'maceio',
#  'kapoeta',
#  'sao joao da barra',
#  'mehamn',
#  'la ronge',
#  'mecca',
#  'esperance',
#  'channel-port aux basques',
#  'higuey',
#  'pannonhalma',
#  'ancud',
#  'bogande',
#  'san jose',
#  'luderitz',
#  'bograd',
#  'griffith',
#  'laguna',
#  'dien bien',
#  'meulaboh',
#  'grindavik',
#  'vilcun',
#  'jaca',
#  'storforshei',
#  'baruun-urt',
#  'utiroa',
#  'bathsheba',
#  'san patricio',
#  'otukpo',
#  'ambodifototra',
#  'saronno',
#  'bud',
#  'oranjemund',
#  'walvis bay',
#  'koshurnikovo',
#  'haines junction',
#  'chibuto',
#  'phuket',
#  'bunia',
#  'gat',
#  'guerrero negro',
#  'havre-saint-pierre',
#  'marsh harbour',
#  'victoria',
#  'ribeira brava',
#  'maromitsa',
#  'khonuu',
#  'tuatapere',
#  'udomlya',
#  'santiago del estero',
#  'soyo',
#  'colesberg',
#  'vanavara',
#  'hervey bay',
#  'santa rosa',
#  'hays',
#  'deder',
#  'ostersund',
#  'namibe',
#  'kushmurun',
#  'assiniboia',
#  'saint george',
#  'uglovskoye',
#  'portland',
#  'upernavik',
#  'eyl',
#  'ilhabela',
#  'ahipara',
#  'mumbwa',
#  'inuvik',
#  'aklavik',
#  'alyangula',
#  'sao filipe',
#  'iskateley',
#  'solomenskoye',
#  'menongue',
#  'the valley',
#  'tuggurt',
#  'imbituba',
#  'bo rai',
#  'sao gabriel da cachoeira',
#  'khorramshahr',
#  'marfino',
#  'talmenka',
#  'moengo',
#  'sioux lookout',
#  'kagadi',
#  'half moon bay',
#  'severnoye',
#  'temirtau',
#  'cape canaveral',
#  'benito juarez',
#  'la palma',
#  'muborak',
#  'kaili',
#  'jodar',
#  'pueblo nuevo',
#  'mandurah',
#  'yuryevets',
#  'quang ngai',
#  'zabid',
#  'batagay-alyta',
#  'ngukurr',
#  'hasaki',
#  'christchurch',
#  'miram shah',
#  'gewane',
#  'saint anthony',
#  'luebo',
#  'kiwira',
#  'doctor pedro p. pena',
#  'nizwa',
#  'narsaq',
#  'lavrentiya',
#  'timra',
#  'kraslava',
#  'mayo',
#  'floro',
#  'udachnyy',
#  'sainte-thecle',
#  'caarapo',
#  'bealanana',
#  'bambous virieux',
#  'clarence town',
#  'alofi',
#  'takoradi',
#  'huarmey',
#  'villacarrillo',
#  'kikwit',
#  'dhidhdhoo',
#  'teya',
#  'sayat',
#  'kamenka',
#  'parakan',
#  'agadez',
#  'kirovsk',
#  'kulhudhuffushi',
#  'buin',
#  'dakar',
#  'thunder bay',
#  'ligayan',
#  'fare',
#  'qaqortoq',
#  'baherden',
#  'tres barras',
#  'saint-augustin',
#  'nuuk',
#  'tsumeb',
#  'gorno-chuyskiy',
#  'pisco',
#  'mindif',
#  'nanga eboko',
#  'ngunguru',
#  'cherskiy',
#  'srednekolymsk',
#  'berlevag',
#  'hukuntsi',
#  'hutang',
#  'kuandian',
#  'tongchuan',
#  'grand river south east',
#  'surab',
#  'oistins',
#  'saraza',
#  'karaul',
#  'dire',
#  'bestobe',
#  'buraydah',
#  'valleyview',
#  'rio gallegos',
#  'tierralta',
#  'mandera',
#  'scarborough',
#  'porto santo',
#  'rodrigues alves',
#  'samarai',
#  'beringovskiy',
#  'manzhouli',
#  'kudahuvadhoo',
#  'vao',
#  'buqayq',
#  'mogadishu',
#  'biltine',
#  'nogliki',
#  'doha',
#  'volkhovskiy',
#  'sisimiut',
#  'amudat',
#  'tautira',
#  'imeni poliny osipenko',
#  'panzhihua',
#  'maarianhamina',
#  'pousat',
#  'norfolk',
#  'shasta lake',
#  'nuevo progreso',
#  'lamesa',
#  'gravdal',
#  'innisfail',
#  'shama',
#  'vila franca do campo',
#  'sumbe',
#  'quelimane',
#  'batie',
#  'bukachacha',
#  'paita',
#  'mormugao',
#  'lasa',
#  'lewistown',
#  'bela',
#  'korhogo',
#  'killybegs',
#  'gariaband',
#  'gunnedah',
#  'acapulco',
#  'yar-sale',
#  'san miguel',
#  'port hardy',
#  'chute-aux-outardes',
#  'baykit',
#  'faanui',
#  'derzhavinsk',
#  'atocha',
#  'gulshat',
#  'mitchell',
#  'yairipok',
#  'lagos',
#  'nagato',
#  'san juan',
#  'atambua',
#  'charlestown',
#  'axim',
#  'rio grande',
#  'dzhebariki-khaya',
#  'beloha',
#  'manta',
#  'aviles',
#  'kipini',
#  'muroto',
#  'chimala',
#  'cabedelo',
#  'kavaratti',
#  'pekin',
#  'azanka',
#  'garoua',
#  'port hedland',
#  'chuka',
#  'malkangiri',
#  'pampa',
#  'miri',
#  'yamada',
#  'zolotinka',
#  'raudeberg',
#  'salihorsk',
#  'kristiansund',
#  'shizuishan',
#  'chateauroux',
#  'makinsk',
#  'jiexiu',
#  'tommot',
#  'tonekabon',
#  'ambilobe',
#  'makokou',
#  'mananara',
#  'chik',
#  'san policarpo',
#  'narasannapeta',
#  'limbang',
#  'oriximina',
#  'puerto leguizamo',
#  'svetlaya',
#  'el centro',
#  'hualmay',
#  'brest',
#  'igunga',
#  'temaraia',
#  'pierre',
#  'port townsend',
#  'egvekinot',
#  'tall kayf',
#  'manokwari',
#  'sembakung',
#  'breves',
#  'maniitsoq',
#  'attawapiskat',
#  'benguela',
#  'asfi',
#  'tondano',
#  'dekoa',
#  'mansa',
#  'palabuhanratu',
#  'peachland',
#  'salalah',
#  'jian',
#  'karamken',
#  'san borja',
#  'aykhal',
#  'denizli',
#  'reo',
#  'satitoa',
#  'noumea']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_weath = requests.get(city_url).json()
city_weath
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c2a4edd670e6> in <module>
# ----> 1 city_weath = requests.get(city_url).json()
#       2 city_weath
#
# NameError: name 'city_url' is not defined

# %%
city_loc = []
city_counter = 1
city_set = 1

#loop through city list(count=creating set)
for count,ele in enumerate(cities): 
    print (count,ele)
    #grouping the cities in sets of 50.
    if (count % 50 == 0 and count >= 50):
        city_set += 1
        city_counter = 0

        
    #adding to the end of the url(ele=city names)
    city_url = url + "&q=" + ele
    print("Processing Record %s of Set %s | %s" % (city_counter, city_set, ele))
    
    #increase city counter
    city_counter += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weath = requests.get(city_url).json()
        
        #country, lon, lat, temp, humidity, cloud factor, wind, date
        country= city_weath["sys"]["country"]
        date= city_weath["dt"]
        lon= city_weath["coord"]["lon"]
        lat= city_weath["coord"]["lat"]
        temp = city_weath["main"]["temp_max"]
        humidity = city_weath["main"]["humidity"]
        cloud_factor = city_weath["clouds"]["all"]
        wind = city_weath["wind"]["speed"]
        
        #append info above into a dict.
        
        city_loc.append({"City":ele,
                        "Country":country,
                        "Date":date,
                        "Longitude":lon,
                        "Latitude":lat,
                        "Max Temperature":temp,
                        "Humidity": humidity,
                        "Cloudiness": cloud_factor,
                        "Wind speed": wind})
        # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Out:
# 0 carballo
# Processing Record 1 of Set 1 | carballo
# 1 ushuaia
# Processing Record 2 of Set 1 | ushuaia
# 2 padang
# Processing Record 3 of Set 1 | padang
# 3 eureka
# Processing Record 4 of Set 1 | eureka
# 4 taolanaro
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# 5 la orilla
# Processing Record 6 of Set 1 | la orilla
# 6 rikitea
# Processing Record 7 of Set 1 | rikitea
# 7 marcona
# Processing Record 8 of Set 1 | marcona
# City not found. Skipping...
# 8 geraldton
# Processing Record 9 of Set 1 | geraldton
# 9 chuy
# Processing Record 10 of Set 1 | chuy
# 10 punta arenas
# Processing Record 11 of Set 1 | punta arenas
# 11 kijang
# Processing Record 12 of Set 1 | kijang
# 12 mar del plata
# Processing Record 13 of Set 1 | mar del plata
# 13 rognan
# Processing Record 14 of Set 1 | rognan
# 14 severo-kurilsk
# Processing Record 15 of Set 1 | severo-kurilsk
# 15 kapaa
# Processing Record 16 of Set 1 | kapaa
# 16 nemuro
# Processing Record 17 of Set 1 | nemuro
# 17 juruti
# Processing Record 18 of Set 1 | juruti
# 18 amderma
# Processing Record 19 of Set 1 | amderma
# City not found. Skipping...
# 19 albany
# Processing Record 20 of Set 1 | albany
# 20 prince rupert
# Processing Record 21 of Set 1 | prince rupert
# 21 nizhneyansk
# Processing Record 22 of Set 1 | nizhneyansk
# City not found. Skipping...
# 22 qaanaaq
# Processing Record 23 of Set 1 | qaanaaq
# 23 ruatoria
# Processing Record 24 of Set 1 | ruatoria
# City not found. Skipping...
# 24 bengkulu
# Processing Record 25 of Set 1 | bengkulu
# 25 ribeira grande
# Processing Record 26 of Set 1 | ribeira grande
# 26 jamestown
# Processing Record 27 of Set 1 | jamestown
# 27 saskylakh
# Processing Record 28 of Set 1 | saskylakh
# 28 busselton
# Processing Record 29 of Set 1 | busselton
# 29 la cruz
# Processing Record 30 of Set 1 | la cruz
# 30 atuona
# Processing Record 31 of Set 1 | atuona
# 31 illoqqortoormiut
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# 32 maxixe
# Processing Record 33 of Set 1 | maxixe
# 33 tra vinh
# Processing Record 34 of Set 1 | tra vinh
# 34 hobart
# Processing Record 35 of Set 1 | hobart
# 35 novopokrovka
# Processing Record 36 of Set 1 | novopokrovka
# 36 huazolotitlan
# Processing Record 37 of Set 1 | huazolotitlan
# City not found. Skipping...
# 37 butaritari
# Processing Record 38 of Set 1 | butaritari
# 38 lebu
# Processing Record 39 of Set 1 | lebu
# 39 shetpe
# Processing Record 40 of Set 1 | shetpe
# 40 nome
# Processing Record 41 of Set 1 | nome
# 41 kahului
# Processing Record 42 of Set 1 | kahului
# 42 ponta delgada
# Processing Record 43 of Set 1 | ponta delgada
# 43 saint andrews
# Processing Record 44 of Set 1 | saint andrews
# 44 norman wells
# Processing Record 45 of Set 1 | norman wells
# 45 lata
# Processing Record 46 of Set 1 | lata
# 46 marawi
# Processing Record 47 of Set 1 | marawi
# 47 bilibino
# Processing Record 48 of Set 1 | bilibino
# 48 te anau
# Processing Record 49 of Set 1 | te anau
# 49 coihaique
# Processing Record 50 of Set 1 | coihaique
# 50 castro
# Processing Record 0 of Set 2 | castro
# 51 tiksi
# Processing Record 1 of Set 2 | tiksi
# 52 carnarvon
# Processing Record 2 of Set 2 | carnarvon
# 53 peniche
# Processing Record 3 of Set 2 | peniche
# 54 new norfolk
# Processing Record 4 of Set 2 | new norfolk
# 55 hammerfest
# Processing Record 5 of Set 2 | hammerfest
# 56 mercedes
# Processing Record 6 of Set 2 | mercedes
# 57 provideniya
# Processing Record 7 of Set 2 | provideniya
# 58 olafsvik
# Processing Record 8 of Set 2 | olafsvik
# 59 honiara
# Processing Record 9 of Set 2 | honiara
# 60 pangkalanbuun
# Processing Record 10 of Set 2 | pangkalanbuun
# 61 isangel
# Processing Record 11 of Set 2 | isangel
# 62 ilulissat
# Processing Record 12 of Set 2 | ilulissat
# 63 paysandu
# Processing Record 13 of Set 2 | paysandu
# 64 codrington
# Processing Record 14 of Set 2 | codrington
# 65 sarankhola
# Processing Record 15 of Set 2 | sarankhola
# 66 tasiilaq
# Processing Record 16 of Set 2 | tasiilaq
# 67 dingle
# Processing Record 17 of Set 2 | dingle
# 68 ginir
# Processing Record 18 of Set 2 | ginir
# 69 kieta
# Processing Record 19 of Set 2 | kieta
# 70 hermanus
# Processing Record 20 of Set 2 | hermanus
# 71 verkhnevilyuysk
# Processing Record 21 of Set 2 | verkhnevilyuysk
# 72 louisbourg
# Processing Record 22 of Set 2 | louisbourg
# City not found. Skipping...
# 73 rong kwang
# Processing Record 23 of Set 2 | rong kwang
# 74 saint-louis
# Processing Record 24 of Set 2 | saint-louis
# 75 clyde river
# Processing Record 25 of Set 2 | clyde river
# 76 saldanha
# Processing Record 26 of Set 2 | saldanha
# 77 auki
# Processing Record 27 of Set 2 | auki
# 78 hilo
# Processing Record 28 of Set 2 | hilo
# 79 hamilton
# Processing Record 29 of Set 2 | hamilton
# 80 hithadhoo
# Processing Record 30 of Set 2 | hithadhoo
# 81 kruisfontein
# Processing Record 31 of Set 2 | kruisfontein
# 82 osorno
# Processing Record 32 of Set 2 | osorno
# 83 nara
# Processing Record 33 of Set 2 | nara
# 84 flin flon
# Processing Record 34 of Set 2 | flin flon
# 85 muros
# Processing Record 35 of Set 2 | muros
# 86 xiaoweizhai
# Processing Record 36 of Set 2 | xiaoweizhai
# 87 nikolskoye
# Processing Record 37 of Set 2 | nikolskoye
# 88 tazovskiy
# Processing Record 38 of Set 2 | tazovskiy
# 89 curup
# Processing Record 39 of Set 2 | curup
# 90 yellowknife
# Processing Record 40 of Set 2 | yellowknife
# 91 bonavista
# Processing Record 41 of Set 2 | bonavista
# 92 bethel
# Processing Record 42 of Set 2 | bethel
# 93 bilma
# Processing Record 43 of Set 2 | bilma
# 94 ust-ishim
# Processing Record 44 of Set 2 | ust-ishim
# 95 genteng
# Processing Record 45 of Set 2 | genteng
# 96 wanning
# Processing Record 46 of Set 2 | wanning
# 97 lompoc
# Processing Record 47 of Set 2 | lompoc
# 98 mahebourg
# Processing Record 48 of Set 2 | mahebourg
# 99 yumen
# Processing Record 49 of Set 2 | yumen
# 100 georgetown
# Processing Record 0 of Set 3 | georgetown
# 101 cape town
# Processing Record 1 of Set 3 | cape town
# 102 mitsamiouli
# Processing Record 2 of Set 3 | mitsamiouli
# 103 port-gentil
# Processing Record 3 of Set 3 | port-gentil
# 104 sovetskiy
# Processing Record 4 of Set 3 | sovetskiy
# 105 sur
# Processing Record 5 of Set 3 | sur
# 106 zunyi
# Processing Record 6 of Set 3 | zunyi
# 107 caravelas
# Processing Record 7 of Set 3 | caravelas
# 108 mehriz
# Processing Record 8 of Set 3 | mehriz
# 109 daru
# Processing Record 9 of Set 3 | daru
# 110 mocuba
# Processing Record 10 of Set 3 | mocuba
# 111 rustenburg
# Processing Record 11 of Set 3 | rustenburg
# 112 vaini
# Processing Record 12 of Set 3 | vaini
# 113 boden
# Processing Record 13 of Set 3 | boden
# 114 hartselle
# Processing Record 14 of Set 3 | hartselle
# 115 cidreira
# Processing Record 15 of Set 3 | cidreira
# 116 barentsburg
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# 117 khash
# Processing Record 17 of Set 3 | khash
# 118 namatanai
# Processing Record 18 of Set 3 | namatanai
# 119 itarema
# Processing Record 19 of Set 3 | itarema
# 120 grand-santi
# Processing Record 20 of Set 3 | grand-santi
# 121 port elizabeth
# Processing Record 21 of Set 3 | port elizabeth
# 122 thompson
# Processing Record 22 of Set 3 | thompson
# 123 yulara
# Processing Record 23 of Set 3 | yulara
# 124 touros
# Processing Record 24 of Set 3 | touros
# 125 lagoa
# Processing Record 25 of Set 3 | lagoa
# 126 cardenas
# Processing Record 26 of Set 3 | cardenas
# 127 lahaina
# Processing Record 27 of Set 3 | lahaina
# 128 gigmoto
# Processing Record 28 of Set 3 | gigmoto
# 129 vostok
# Processing Record 29 of Set 3 | vostok
# 130 port alfred
# Processing Record 30 of Set 3 | port alfred
# 131 kerema
# Processing Record 31 of Set 3 | kerema
# 132 zyryanka
# Processing Record 32 of Set 3 | zyryanka
# 133 hede
# Processing Record 33 of Set 3 | hede
# 134 gushikawa
# Processing Record 34 of Set 3 | gushikawa
# 135 tura
# Processing Record 35 of Set 3 | tura
# 136 torbay
# Processing Record 36 of Set 3 | torbay
# 137 avarua
# Processing Record 37 of Set 3 | avarua
# 138 japura
# Processing Record 38 of Set 3 | japura
# 139 la asuncion
# Processing Record 39 of Set 3 | la asuncion
# 140 bocas del toro
# Processing Record 40 of Set 3 | bocas del toro
# 141 port blair
# Processing Record 41 of Set 3 | port blair
# 142 bac can
# Processing Record 42 of Set 3 | bac can
# City not found. Skipping...
# 143 znamenskoye
# Processing Record 43 of Set 3 | znamenskoye
# 144 puerto ayora
# Processing Record 44 of Set 3 | puerto ayora
# 145 zhigansk
# Processing Record 45 of Set 3 | zhigansk
# 146 tarakan
# Processing Record 46 of Set 3 | tarakan
# 147 ryotsu
# Processing Record 47 of Set 3 | ryotsu
# 148 solnechnyy
# Processing Record 48 of Set 3 | solnechnyy
# 149 tuktoyaktuk
# Processing Record 49 of Set 3 | tuktoyaktuk
# 150 bluff
# Processing Record 0 of Set 4 | bluff
# 151 tumannyy
# Processing Record 1 of Set 4 | tumannyy
# City not found. Skipping...
# 152 itoman
# Processing Record 2 of Set 4 | itoman
# 153 san cristobal
# Processing Record 3 of Set 4 | san cristobal
# 154 camacha
# Processing Record 4 of Set 4 | camacha
# 155 dunedin
# Processing Record 5 of Set 4 | dunedin
# 156 sentyabrskiy
# Processing Record 6 of Set 4 | sentyabrskiy
# City not found. Skipping...
# 157 meyungs
# Processing Record 7 of Set 4 | meyungs
# City not found. Skipping...
# 158 shache
# Processing Record 8 of Set 4 | shache
# 159 arraial do cabo
# Processing Record 9 of Set 4 | arraial do cabo
# 160 umm kaddadah
# Processing Record 10 of Set 4 | umm kaddadah
# 161 stromness
# Processing Record 11 of Set 4 | stromness
# 162 dikson
# Processing Record 12 of Set 4 | dikson
# 163 souillac
# Processing Record 13 of Set 4 | souillac
# 164 chittur
# Processing Record 14 of Set 4 | chittur
# 165 klaksvik
# Processing Record 15 of Set 4 | klaksvik
# 166 galiwinku
# Processing Record 16 of Set 4 | galiwinku
# City not found. Skipping...
# 167 chagda
# Processing Record 17 of Set 4 | chagda
# City not found. Skipping...
# 168 san ramon
# Processing Record 18 of Set 4 | san ramon
# 169 avera
# Processing Record 19 of Set 4 | avera
# 170 necochea
# Processing Record 20 of Set 4 | necochea
# 171 saint-pierre
# Processing Record 21 of Set 4 | saint-pierre
# 172 belushya guba
# Processing Record 22 of Set 4 | belushya guba
# City not found. Skipping...
# 173 ixtapa
# Processing Record 23 of Set 4 | ixtapa
# 174 mataura
# Processing Record 24 of Set 4 | mataura
# 175 kokkola
# Processing Record 25 of Set 4 | kokkola
# 176 khatanga
# Processing Record 26 of Set 4 | khatanga
# 177 ust-kamchatsk
# Processing Record 27 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# 178 bubaque
# Processing Record 28 of Set 4 | bubaque
# 179 bredasdorp
# Processing Record 29 of Set 4 | bredasdorp
# 180 darnah
# Processing Record 30 of Set 4 | darnah
# 181 barrow
# Processing Record 31 of Set 4 | barrow
# 182 saint-philippe
# Processing Record 32 of Set 4 | saint-philippe
# 183 tabiauea
# Processing Record 33 of Set 4 | tabiauea
# City not found. Skipping...
# 184 richards bay
# Processing Record 34 of Set 4 | richards bay
# 185 morehead
# Processing Record 35 of Set 4 | morehead
# 186 ponta do sol
# Processing Record 36 of Set 4 | ponta do sol
# 187 leningradskiy
# Processing Record 37 of Set 4 | leningradskiy
# 188 svetlogorsk
# Processing Record 38 of Set 4 | svetlogorsk
# 189 sayaxche
# Processing Record 39 of Set 4 | sayaxche
# 190 kodiak
# Processing Record 40 of Set 4 | kodiak
# 191 punto fijo
# Processing Record 41 of Set 4 | punto fijo
# 192 tshikapa
# Processing Record 42 of Set 4 | tshikapa
# 193 marystown
# Processing Record 43 of Set 4 | marystown
# 194 east london
# Processing Record 44 of Set 4 | east london
# 195 margate
# Processing Record 45 of Set 4 | margate
# 196 samusu
# Processing Record 46 of Set 4 | samusu
# City not found. Skipping...
# 197 cap malheureux
# Processing Record 47 of Set 4 | cap malheureux
# 198 airai
# Processing Record 48 of Set 4 | airai
# 199 kuytun
# Processing Record 49 of Set 4 | kuytun
# 200 staryy nadym
# Processing Record 0 of Set 5 | staryy nadym
# 201 fortuna
# Processing Record 1 of Set 5 | fortuna
# 202 tiznit
# Processing Record 2 of Set 5 | tiznit
# 203 labutta
# Processing Record 3 of Set 5 | labutta
# City not found. Skipping...
# 204 agirish
# Processing Record 4 of Set 5 | agirish
# 205 ust-karsk
# Processing Record 5 of Set 5 | ust-karsk
# 206 davila
# Processing Record 6 of Set 5 | davila
# 207 ola
# Processing Record 7 of Set 5 | ola
# 208 altay
# Processing Record 8 of Set 5 | altay
# 209 praxedis guerrero
# Processing Record 9 of Set 5 | praxedis guerrero
# 210 wolfville
# Processing Record 10 of Set 5 | wolfville
# 211 palmer
# Processing Record 11 of Set 5 | palmer
# 212 ouadda
# Processing Record 12 of Set 5 | ouadda
# 213 villazon
# Processing Record 13 of Set 5 | villazon
# 214 belyy yar
# Processing Record 14 of Set 5 | belyy yar
# 215 carutapera
# Processing Record 15 of Set 5 | carutapera
# 216 chokurdakh
# Processing Record 16 of Set 5 | chokurdakh
# 217 krasnovishersk
# Processing Record 17 of Set 5 | krasnovishersk
# 218 chapais
# Processing Record 18 of Set 5 | chapais
# 219 manado
# Processing Record 19 of Set 5 | manado
# 220 kutum
# Processing Record 20 of Set 5 | kutum
# 221 vila velha
# Processing Record 21 of Set 5 | vila velha
# 222 porto de moz
# Processing Record 22 of Set 5 | porto de moz
# 223 jacareacanga
# Processing Record 23 of Set 5 | jacareacanga
# 224 alexandria
# Processing Record 24 of Set 5 | alexandria
# 225 el alto
# Processing Record 25 of Set 5 | el alto
# 226 maple creek
# Processing Record 26 of Set 5 | maple creek
# 227 freiberg
# Processing Record 27 of Set 5 | freiberg
# 228 yefira
# Processing Record 28 of Set 5 | yefira
# City not found. Skipping...
# 229 shingu
# Processing Record 29 of Set 5 | shingu
# 230 kavieng
# Processing Record 30 of Set 5 | kavieng
# 231 longyearbyen
# Processing Record 31 of Set 5 | longyearbyen
# 232 tsihombe
# Processing Record 32 of Set 5 | tsihombe
# City not found. Skipping...
# 233 san andres
# Processing Record 33 of Set 5 | san andres
# 234 huayang
# Processing Record 34 of Set 5 | huayang
# 235 hohhot
# Processing Record 35 of Set 5 | hohhot
# 236 bourail
# Processing Record 36 of Set 5 | bourail
# 237 isfara
# Processing Record 37 of Set 5 | isfara
# 238 milingimbi
# Processing Record 38 of Set 5 | milingimbi
# City not found. Skipping...
# 239 nanortalik
# Processing Record 39 of Set 5 | nanortalik
# 240 soldato-aleksandrovskoye
# Processing Record 40 of Set 5 | soldato-aleksandrovskoye
# 241 ostrovnoy
# Processing Record 41 of Set 5 | ostrovnoy
# 242 dickinson
# Processing Record 42 of Set 5 | dickinson
# 243 sangar
# Processing Record 43 of Set 5 | sangar
# 244 bozeman
# Processing Record 44 of Set 5 | bozeman
# 245 izhma
# Processing Record 45 of Set 5 | izhma
# 246 sal rei
# Processing Record 46 of Set 5 | sal rei
# 247 pangody
# Processing Record 47 of Set 5 | pangody
# 248 mamlyutka
# Processing Record 48 of Set 5 | mamlyutka
# 249 mount gambier
# Processing Record 49 of Set 5 | mount gambier
# 250 mys shmidta
# Processing Record 0 of Set 6 | mys shmidta
# City not found. Skipping...
# 251 yakima
# Processing Record 1 of Set 6 | yakima
# 252 cabo san lucas
# Processing Record 2 of Set 6 | cabo san lucas
# 253 la romana
# Processing Record 3 of Set 6 | la romana
# 254 xinyu
# Processing Record 4 of Set 6 | xinyu
# 255 le vauclin
# Processing Record 5 of Set 6 | le vauclin
# 256 serebryansk
# Processing Record 6 of Set 6 | serebryansk
# 257 kabalo
# Processing Record 7 of Set 6 | kabalo
# 258 bargal
# Processing Record 8 of Set 6 | bargal
# City not found. Skipping...
# 259 mocajuba
# Processing Record 9 of Set 6 | mocajuba
# 260 gambiran
# Processing Record 10 of Set 6 | gambiran
# 261 gamba
# Processing Record 11 of Set 6 | gamba
# 262 usinsk
# Processing Record 12 of Set 6 | usinsk
# 263 bayan
# Processing Record 13 of Set 6 | bayan
# 264 sylacauga
# Processing Record 14 of Set 6 | sylacauga
# 265 puerto escondido
# Processing Record 15 of Set 6 | puerto escondido
# 266 mattru
# Processing Record 16 of Set 6 | mattru
# 267 batagay
# Processing Record 17 of Set 6 | batagay
# 268 kerrville
# Processing Record 18 of Set 6 | kerrville
# 269 tucupita
# Processing Record 19 of Set 6 | tucupita
# 270 husavik
# Processing Record 20 of Set 6 | husavik
# 271 eyrarbakki
# Processing Record 21 of Set 6 | eyrarbakki
# 272 katsuura
# Processing Record 22 of Set 6 | katsuura
# 273 lincoln
# Processing Record 23 of Set 6 | lincoln
# 274 pevek
# Processing Record 24 of Set 6 | pevek
# 275 manicore
# Processing Record 25 of Set 6 | manicore
# 276 weiser
# Processing Record 26 of Set 6 | weiser
# 277 tessalit
# Processing Record 27 of Set 6 | tessalit
# 278 belmonte
# Processing Record 28 of Set 6 | belmonte
# 279 selam
# Processing Record 29 of Set 6 | selam
# 280 jinchang
# Processing Record 30 of Set 6 | jinchang
# 281 kiama
# Processing Record 31 of Set 6 | kiama
# 282 kudinovo
# Processing Record 32 of Set 6 | kudinovo
# 283 papanasam
# Processing Record 33 of Set 6 | papanasam
# 284 russell
# Processing Record 34 of Set 6 | russell
# 285 faya
# Processing Record 35 of Set 6 | faya
# 286 ascension
# Processing Record 36 of Set 6 | ascension
# 287 birpur
# Processing Record 37 of Set 6 | birpur
# 288 macroom
# Processing Record 38 of Set 6 | macroom
# 289 ilheus
# Processing Record 39 of Set 6 | ilheus
# 290 abu samrah
# Processing Record 40 of Set 6 | abu samrah
# 291 sinnamary
# Processing Record 41 of Set 6 | sinnamary
# 292 chifeng
# Processing Record 42 of Set 6 | chifeng
# 293 talnakh
# Processing Record 43 of Set 6 | talnakh
# 294 iqaluit
# Processing Record 44 of Set 6 | iqaluit
# 295 kyabram
# Processing Record 45 of Set 6 | kyabram
# 296 male
# Processing Record 46 of Set 6 | male
# 297 joetsu
# Processing Record 47 of Set 6 | joetsu
# 298 vacaria
# Processing Record 48 of Set 6 | vacaria
# 299 kongolo
# Processing Record 49 of Set 6 | kongolo
# 300 khor
# Processing Record 0 of Set 7 | khor
# 301 waipawa
# Processing Record 1 of Set 7 | waipawa
# 302 buckeye
# Processing Record 2 of Set 7 | buckeye
# 303 quatre cocos
# Processing Record 3 of Set 7 | quatre cocos
# 304 teguise
# Processing Record 4 of Set 7 | teguise
# 305 klyuchi
# Processing Record 5 of Set 7 | klyuchi
# 306 mao
# Processing Record 6 of Set 7 | mao
# 307 luganville
# Processing Record 7 of Set 7 | luganville
# 308 sitka
# Processing Record 8 of Set 7 | sitka
# 309 kamogawa
# Processing Record 9 of Set 7 | kamogawa
# 310 najran
# Processing Record 10 of Set 7 | najran
# 311 petatlan
# Processing Record 11 of Set 7 | petatlan
# 312 korla
# Processing Record 12 of Set 7 | korla
# 313 safwah
# Processing Record 13 of Set 7 | safwah
# City not found. Skipping...
# 314 ketchikan
# Processing Record 14 of Set 7 | ketchikan
# 315 saint-paul
# Processing Record 15 of Set 7 | saint-paul
# 316 grand gaube
# Processing Record 16 of Set 7 | grand gaube
# 317 kenai
# Processing Record 17 of Set 7 | kenai
# 318 maceio
# Processing Record 18 of Set 7 | maceio
# 319 kapoeta
# Processing Record 19 of Set 7 | kapoeta
# 320 sao joao da barra
# Processing Record 20 of Set 7 | sao joao da barra
# 321 mehamn
# Processing Record 21 of Set 7 | mehamn
# 322 la ronge
# Processing Record 22 of Set 7 | la ronge
# 323 mecca
# Processing Record 23 of Set 7 | mecca
# 324 esperance
# Processing Record 24 of Set 7 | esperance
# 325 channel-port aux basques
# Processing Record 25 of Set 7 | channel-port aux basques
# 326 higuey
# Processing Record 26 of Set 7 | higuey
# City not found. Skipping...
# 327 pannonhalma
# Processing Record 27 of Set 7 | pannonhalma
# 328 ancud
# Processing Record 28 of Set 7 | ancud
# 329 bogande
# Processing Record 29 of Set 7 | bogande
# 330 san jose
# Processing Record 30 of Set 7 | san jose
# 331 luderitz
# Processing Record 31 of Set 7 | luderitz
# 332 bograd
# Processing Record 32 of Set 7 | bograd
# 333 griffith
# Processing Record 33 of Set 7 | griffith
# 334 laguna
# Processing Record 34 of Set 7 | laguna
# 335 dien bien
# Processing Record 35 of Set 7 | dien bien
# City not found. Skipping...
# 336 meulaboh
# Processing Record 36 of Set 7 | meulaboh
# 337 grindavik
# Processing Record 37 of Set 7 | grindavik
# 338 vilcun
# Processing Record 38 of Set 7 | vilcun
# 339 jaca
# Processing Record 39 of Set 7 | jaca
# 340 storforshei
# Processing Record 40 of Set 7 | storforshei
# 341 baruun-urt
# Processing Record 41 of Set 7 | baruun-urt
# 342 utiroa
# Processing Record 42 of Set 7 | utiroa
# City not found. Skipping...
# 343 bathsheba
# Processing Record 43 of Set 7 | bathsheba
# 344 san patricio
# Processing Record 44 of Set 7 | san patricio
# 345 otukpo
# Processing Record 45 of Set 7 | otukpo
# 346 ambodifototra
# Processing Record 46 of Set 7 | ambodifototra
# City not found. Skipping...
# 347 saronno
# Processing Record 47 of Set 7 | saronno
# 348 bud
# Processing Record 48 of Set 7 | bud
# 349 oranjemund
# Processing Record 49 of Set 7 | oranjemund
# 350 walvis bay
# Processing Record 0 of Set 8 | walvis bay
# 351 koshurnikovo
# Processing Record 1 of Set 8 | koshurnikovo
# 352 haines junction
# Processing Record 2 of Set 8 | haines junction
# 353 chibuto
# Processing Record 3 of Set 8 | chibuto
# 354 phuket
# Processing Record 4 of Set 8 | phuket
# 355 bunia
# Processing Record 5 of Set 8 | bunia
# 356 gat
# Processing Record 6 of Set 8 | gat
# 357 guerrero negro
# Processing Record 7 of Set 8 | guerrero negro
# 358 havre-saint-pierre
# Processing Record 8 of Set 8 | havre-saint-pierre
# 359 marsh harbour
# Processing Record 9 of Set 8 | marsh harbour
# 360 victoria
# Processing Record 10 of Set 8 | victoria
# 361 ribeira brava
# Processing Record 11 of Set 8 | ribeira brava
# 362 maromitsa
# Processing Record 12 of Set 8 | maromitsa
# 363 khonuu
# Processing Record 13 of Set 8 | khonuu
# City not found. Skipping...
# 364 tuatapere
# Processing Record 14 of Set 8 | tuatapere
# 365 udomlya
# Processing Record 15 of Set 8 | udomlya
# 366 santiago del estero
# Processing Record 16 of Set 8 | santiago del estero
# 367 soyo
# Processing Record 17 of Set 8 | soyo
# 368 colesberg
# Processing Record 18 of Set 8 | colesberg
# 369 vanavara
# Processing Record 19 of Set 8 | vanavara
# 370 hervey bay
# Processing Record 20 of Set 8 | hervey bay
# 371 santa rosa
# Processing Record 21 of Set 8 | santa rosa
# 372 hays
# Processing Record 22 of Set 8 | hays
# 373 deder
# Processing Record 23 of Set 8 | deder
# 374 ostersund
# Processing Record 24 of Set 8 | ostersund
# 375 namibe
# Processing Record 25 of Set 8 | namibe
# 376 kushmurun
# Processing Record 26 of Set 8 | kushmurun
# 377 assiniboia
# Processing Record 27 of Set 8 | assiniboia
# 378 saint george
# Processing Record 28 of Set 8 | saint george
# 379 uglovskoye
# Processing Record 29 of Set 8 | uglovskoye
# 380 portland
# Processing Record 30 of Set 8 | portland
# 381 upernavik
# Processing Record 31 of Set 8 | upernavik
# 382 eyl
# Processing Record 32 of Set 8 | eyl
# 383 ilhabela
# Processing Record 33 of Set 8 | ilhabela
# 384 ahipara
# Processing Record 34 of Set 8 | ahipara
# 385 mumbwa
# Processing Record 35 of Set 8 | mumbwa
# 386 inuvik
# Processing Record 36 of Set 8 | inuvik
# 387 aklavik
# Processing Record 37 of Set 8 | aklavik
# 388 alyangula
# Processing Record 38 of Set 8 | alyangula
# 389 sao filipe
# Processing Record 39 of Set 8 | sao filipe
# 390 iskateley
# Processing Record 40 of Set 8 | iskateley
# 391 solomenskoye
# Processing Record 41 of Set 8 | solomenskoye
# 392 menongue
# Processing Record 42 of Set 8 | menongue
# 393 the valley
# Processing Record 43 of Set 8 | the valley
# 394 tuggurt
# Processing Record 44 of Set 8 | tuggurt
# City not found. Skipping...
# 395 imbituba
# Processing Record 45 of Set 8 | imbituba
# 396 bo rai
# Processing Record 46 of Set 8 | bo rai
# 397 sao gabriel da cachoeira
# Processing Record 47 of Set 8 | sao gabriel da cachoeira
# 398 khorramshahr
# Processing Record 48 of Set 8 | khorramshahr
# 399 marfino
# Processing Record 49 of Set 8 | marfino
# 400 talmenka
# Processing Record 0 of Set 9 | talmenka
# 401 moengo
# Processing Record 1 of Set 9 | moengo
# 402 sioux lookout
# Processing Record 2 of Set 9 | sioux lookout
# 403 kagadi
# Processing Record 3 of Set 9 | kagadi
# 404 half moon bay
# Processing Record 4 of Set 9 | half moon bay
# 405 severnoye
# Processing Record 5 of Set 9 | severnoye
# 406 temirtau
# Processing Record 6 of Set 9 | temirtau
# 407 cape canaveral
# Processing Record 7 of Set 9 | cape canaveral
# 408 benito juarez
# Processing Record 8 of Set 9 | benito juarez
# 409 la palma
# Processing Record 9 of Set 9 | la palma
# 410 muborak
# Processing Record 10 of Set 9 | muborak
# 411 kaili
# Processing Record 11 of Set 9 | kaili
# 412 jodar
# Processing Record 12 of Set 9 | jodar
# 413 pueblo nuevo
# Processing Record 13 of Set 9 | pueblo nuevo
# 414 mandurah
# Processing Record 14 of Set 9 | mandurah
# 415 yuryevets
# Processing Record 15 of Set 9 | yuryevets
# 416 quang ngai
# Processing Record 16 of Set 9 | quang ngai
# 417 zabid
# Processing Record 17 of Set 9 | zabid
# 418 batagay-alyta
# Processing Record 18 of Set 9 | batagay-alyta
# 419 ngukurr
# Processing Record 19 of Set 9 | ngukurr
# City not found. Skipping...
# 420 hasaki
# Processing Record 20 of Set 9 | hasaki
# 421 christchurch
# Processing Record 21 of Set 9 | christchurch
# 422 miram shah
# Processing Record 22 of Set 9 | miram shah
# 423 gewane
# Processing Record 23 of Set 9 | gewane
# 424 saint anthony
# Processing Record 24 of Set 9 | saint anthony
# 425 luebo
# Processing Record 25 of Set 9 | luebo
# 426 kiwira
# Processing Record 26 of Set 9 | kiwira
# 427 doctor pedro p. pena
# Processing Record 27 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# 428 nizwa
# Processing Record 28 of Set 9 | nizwa
# 429 narsaq
# Processing Record 29 of Set 9 | narsaq
# 430 lavrentiya
# Processing Record 30 of Set 9 | lavrentiya
# 431 timra
# Processing Record 31 of Set 9 | timra
# 432 kraslava
# Processing Record 32 of Set 9 | kraslava
# 433 mayo
# Processing Record 33 of Set 9 | mayo
# 434 floro
# Processing Record 34 of Set 9 | floro
# 435 udachnyy
# Processing Record 35 of Set 9 | udachnyy
# 436 sainte-thecle
# Processing Record 36 of Set 9 | sainte-thecle
# 437 caarapo
# Processing Record 37 of Set 9 | caarapo
# 438 bealanana
# Processing Record 38 of Set 9 | bealanana
# 439 bambous virieux
# Processing Record 39 of Set 9 | bambous virieux
# 440 clarence town
# Processing Record 40 of Set 9 | clarence town
# 441 alofi
# Processing Record 41 of Set 9 | alofi
# 442 takoradi
# Processing Record 42 of Set 9 | takoradi
# 443 huarmey
# Processing Record 43 of Set 9 | huarmey
# 444 villacarrillo
# Processing Record 44 of Set 9 | villacarrillo
# 445 kikwit
# Processing Record 45 of Set 9 | kikwit
# 446 dhidhdhoo
# Processing Record 46 of Set 9 | dhidhdhoo
# 447 teya
# Processing Record 47 of Set 9 | teya
# 448 sayat
# Processing Record 48 of Set 9 | sayat
# 449 kamenka
# Processing Record 49 of Set 9 | kamenka
# 450 parakan
# Processing Record 0 of Set 10 | parakan
# 451 agadez
# Processing Record 1 of Set 10 | agadez
# 452 kirovsk
# Processing Record 2 of Set 10 | kirovsk
# 453 kulhudhuffushi
# Processing Record 3 of Set 10 | kulhudhuffushi
# 454 buin
# Processing Record 4 of Set 10 | buin
# 455 dakar
# Processing Record 5 of Set 10 | dakar
# 456 thunder bay
# Processing Record 6 of Set 10 | thunder bay
# 457 ligayan
# Processing Record 7 of Set 10 | ligayan
# 458 fare
# Processing Record 8 of Set 10 | fare
# 459 qaqortoq
# Processing Record 9 of Set 10 | qaqortoq
# 460 baherden
# Processing Record 10 of Set 10 | baherden
# 461 tres barras
# Processing Record 11 of Set 10 | tres barras
# 462 saint-augustin
# Processing Record 12 of Set 10 | saint-augustin
# 463 nuuk
# Processing Record 13 of Set 10 | nuuk
# 464 tsumeb
# Processing Record 14 of Set 10 | tsumeb
# 465 gorno-chuyskiy
# Processing Record 15 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# 466 pisco
# Processing Record 16 of Set 10 | pisco
# 467 mindif
# Processing Record 17 of Set 10 | mindif
# 468 nanga eboko
# Processing Record 18 of Set 10 | nanga eboko
# 469 ngunguru
# Processing Record 19 of Set 10 | ngunguru
# 470 cherskiy
# Processing Record 20 of Set 10 | cherskiy
# 471 srednekolymsk
# Processing Record 21 of Set 10 | srednekolymsk
# 472 berlevag
# Processing Record 22 of Set 10 | berlevag
# 473 hukuntsi
# Processing Record 23 of Set 10 | hukuntsi
# 474 hutang
# Processing Record 24 of Set 10 | hutang
# 475 kuandian
# Processing Record 25 of Set 10 | kuandian
# 476 tongchuan
# Processing Record 26 of Set 10 | tongchuan
# 477 grand river south east
# Processing Record 27 of Set 10 | grand river south east
# City not found. Skipping...
# 478 surab
# Processing Record 28 of Set 10 | surab
# 479 oistins
# Processing Record 29 of Set 10 | oistins
# 480 saraza
# Processing Record 30 of Set 10 | saraza
# 481 karaul
# Processing Record 31 of Set 10 | karaul
# City not found. Skipping...
# 482 dire
# Processing Record 32 of Set 10 | dire
# 483 bestobe
# Processing Record 33 of Set 10 | bestobe
# 484 buraydah
# Processing Record 34 of Set 10 | buraydah
# 485 valleyview
# Processing Record 35 of Set 10 | valleyview
# 486 rio gallegos
# Processing Record 36 of Set 10 | rio gallegos
# 487 tierralta
# Processing Record 37 of Set 10 | tierralta
# 488 mandera
# Processing Record 38 of Set 10 | mandera
# 489 scarborough
# Processing Record 39 of Set 10 | scarborough
# 490 porto santo
# Processing Record 40 of Set 10 | porto santo
# 491 rodrigues alves
# Processing Record 41 of Set 10 | rodrigues alves
# 492 samarai
# Processing Record 42 of Set 10 | samarai
# 493 beringovskiy
# Processing Record 43 of Set 10 | beringovskiy
# 494 manzhouli
# Processing Record 44 of Set 10 | manzhouli
# 495 kudahuvadhoo
# Processing Record 45 of Set 10 | kudahuvadhoo
# 496 vao
# Processing Record 46 of Set 10 | vao
# 497 buqayq
# Processing Record 47 of Set 10 | buqayq
# City not found. Skipping...
# 498 mogadishu
# Processing Record 48 of Set 10 | mogadishu
# 499 biltine
# Processing Record 49 of Set 10 | biltine
# 500 nogliki
# Processing Record 0 of Set 11 | nogliki
# 501 doha
# Processing Record 1 of Set 11 | doha
# 502 volkhovskiy
# Processing Record 2 of Set 11 | volkhovskiy
# 503 sisimiut
# Processing Record 3 of Set 11 | sisimiut
# 504 amudat
# Processing Record 4 of Set 11 | amudat
# 505 tautira
# Processing Record 5 of Set 11 | tautira
# 506 imeni poliny osipenko
# Processing Record 6 of Set 11 | imeni poliny osipenko
# 507 panzhihua
# Processing Record 7 of Set 11 | panzhihua
# 508 maarianhamina
# Processing Record 8 of Set 11 | maarianhamina
# 509 pousat
# Processing Record 9 of Set 11 | pousat
# City not found. Skipping...
# 510 norfolk
# Processing Record 10 of Set 11 | norfolk
# 511 shasta lake
# Processing Record 11 of Set 11 | shasta lake
# 512 nuevo progreso
# Processing Record 12 of Set 11 | nuevo progreso
# 513 lamesa
# Processing Record 13 of Set 11 | lamesa
# 514 gravdal
# Processing Record 14 of Set 11 | gravdal
# 515 innisfail
# Processing Record 15 of Set 11 | innisfail
# 516 shama
# Processing Record 16 of Set 11 | shama
# 517 vila franca do campo
# Processing Record 17 of Set 11 | vila franca do campo
# 518 sumbe
# Processing Record 18 of Set 11 | sumbe
# 519 quelimane
# Processing Record 19 of Set 11 | quelimane
# 520 batie
# Processing Record 20 of Set 11 | batie
# 521 bukachacha
# Processing Record 21 of Set 11 | bukachacha
# 522 paita
# Processing Record 22 of Set 11 | paita
# 523 mormugao
# Processing Record 23 of Set 11 | mormugao
# 524 lasa
# Processing Record 24 of Set 11 | lasa
# 525 lewistown
# Processing Record 25 of Set 11 | lewistown
# 526 bela
# Processing Record 26 of Set 11 | bela
# 527 korhogo
# Processing Record 27 of Set 11 | korhogo
# 528 killybegs
# Processing Record 28 of Set 11 | killybegs
# 529 gariaband
# Processing Record 29 of Set 11 | gariaband
# 530 gunnedah
# Processing Record 30 of Set 11 | gunnedah
# 531 acapulco
# Processing Record 31 of Set 11 | acapulco
# 532 yar-sale
# Processing Record 32 of Set 11 | yar-sale
# 533 san miguel
# Processing Record 33 of Set 11 | san miguel
# 534 port hardy
# Processing Record 34 of Set 11 | port hardy
# 535 chute-aux-outardes
# Processing Record 35 of Set 11 | chute-aux-outardes
# 536 baykit
# Processing Record 36 of Set 11 | baykit
# 537 faanui
# Processing Record 37 of Set 11 | faanui
# 538 derzhavinsk
# Processing Record 38 of Set 11 | derzhavinsk
# 539 atocha
# Processing Record 39 of Set 11 | atocha
# 540 gulshat
# Processing Record 40 of Set 11 | gulshat
# City not found. Skipping...
# 541 mitchell
# Processing Record 41 of Set 11 | mitchell
# 542 yairipok
# Processing Record 42 of Set 11 | yairipok
# 543 lagos
# Processing Record 43 of Set 11 | lagos
# 544 nagato
# Processing Record 44 of Set 11 | nagato
# 545 san juan
# Processing Record 45 of Set 11 | san juan
# 546 atambua
# Processing Record 46 of Set 11 | atambua
# 547 charlestown
# Processing Record 47 of Set 11 | charlestown
# 548 axim
# Processing Record 48 of Set 11 | axim
# 549 rio grande
# Processing Record 49 of Set 11 | rio grande
# 550 dzhebariki-khaya
# Processing Record 0 of Set 12 | dzhebariki-khaya
# 551 beloha
# Processing Record 1 of Set 12 | beloha
# 552 manta
# Processing Record 2 of Set 12 | manta
# 553 aviles
# Processing Record 3 of Set 12 | aviles
# 554 kipini
# Processing Record 4 of Set 12 | kipini
# 555 muroto
# Processing Record 5 of Set 12 | muroto
# 556 chimala
# Processing Record 6 of Set 12 | chimala
# 557 cabedelo
# Processing Record 7 of Set 12 | cabedelo
# 558 kavaratti
# Processing Record 8 of Set 12 | kavaratti
# 559 pekin
# Processing Record 9 of Set 12 | pekin
# 560 azanka
# Processing Record 10 of Set 12 | azanka
# 561 garoua
# Processing Record 11 of Set 12 | garoua
# 562 port hedland
# Processing Record 12 of Set 12 | port hedland
# 563 chuka
# Processing Record 13 of Set 12 | chuka
# 564 malkangiri
# Processing Record 14 of Set 12 | malkangiri
# 565 pampa
# Processing Record 15 of Set 12 | pampa
# 566 miri
# Processing Record 16 of Set 12 | miri
# 567 yamada
# Processing Record 17 of Set 12 | yamada
# 568 zolotinka
# Processing Record 18 of Set 12 | zolotinka
# City not found. Skipping...
# 569 raudeberg
# Processing Record 19 of Set 12 | raudeberg
# 570 salihorsk
# Processing Record 20 of Set 12 | salihorsk
# 571 kristiansund
# Processing Record 21 of Set 12 | kristiansund
# 572 shizuishan
# Processing Record 22 of Set 12 | shizuishan
# 573 chateauroux
# Processing Record 23 of Set 12 | chateauroux
# 574 makinsk
# Processing Record 24 of Set 12 | makinsk
# 575 jiexiu
# Processing Record 25 of Set 12 | jiexiu
# 576 tommot
# Processing Record 26 of Set 12 | tommot
# 577 tonekabon
# Processing Record 27 of Set 12 | tonekabon
# 578 ambilobe
# Processing Record 28 of Set 12 | ambilobe
# 579 makokou
# Processing Record 29 of Set 12 | makokou
# 580 mananara
# Processing Record 30 of Set 12 | mananara
# 581 chik
# Processing Record 31 of Set 12 | chik
# 582 san policarpo
# Processing Record 32 of Set 12 | san policarpo
# 583 narasannapeta
# Processing Record 33 of Set 12 | narasannapeta
# 584 limbang
# Processing Record 34 of Set 12 | limbang
# 585 oriximina
# Processing Record 35 of Set 12 | oriximina
# 586 puerto leguizamo
# Processing Record 36 of Set 12 | puerto leguizamo
# 587 svetlaya
# Processing Record 37 of Set 12 | svetlaya
# 588 el centro
# Processing Record 38 of Set 12 | el centro
# 589 hualmay
# Processing Record 39 of Set 12 | hualmay
# 590 brest
# Processing Record 40 of Set 12 | brest
# 591 igunga
# Processing Record 41 of Set 12 | igunga
# 592 temaraia
# Processing Record 42 of Set 12 | temaraia
# City not found. Skipping...
# 593 pierre
# Processing Record 43 of Set 12 | pierre
# 594 port townsend
# Processing Record 44 of Set 12 | port townsend
# 595 egvekinot
# Processing Record 45 of Set 12 | egvekinot
# 596 tall kayf
# Processing Record 46 of Set 12 | tall kayf
# 597 manokwari
# Processing Record 47 of Set 12 | manokwari
# 598 sembakung
# Processing Record 48 of Set 12 | sembakung
# 599 breves
# Processing Record 49 of Set 12 | breves
# 600 maniitsoq
# Processing Record 0 of Set 13 | maniitsoq
# 601 attawapiskat
# Processing Record 1 of Set 13 | attawapiskat
# City not found. Skipping...
# 602 benguela
# Processing Record 2 of Set 13 | benguela
# 603 asfi
# Processing Record 3 of Set 13 | asfi
# 604 tondano
# Processing Record 4 of Set 13 | tondano
# 605 dekoa
# Processing Record 5 of Set 13 | dekoa
# City not found. Skipping...
# 606 mansa
# Processing Record 6 of Set 13 | mansa
# 607 palabuhanratu
# Processing Record 7 of Set 13 | palabuhanratu
# City not found. Skipping...
# 608 peachland
# Processing Record 8 of Set 13 | peachland
# 609 salalah
# Processing Record 9 of Set 13 | salalah
# 610 jian
# Processing Record 10 of Set 13 | jian
# 611 karamken
# Processing Record 11 of Set 13 | karamken
# City not found. Skipping...
# 612 san borja
# Processing Record 12 of Set 13 | san borja
# 613 aykhal
# Processing Record 13 of Set 13 | aykhal
# 614 denizli
# Processing Record 14 of Set 13 | denizli
# 615 reo
# Processing Record 15 of Set 13 | reo
# 616 satitoa
# Processing Record 16 of Set 13 | satitoa
# City not found. Skipping...
# 617 noumea
# Processing Record 17 of Set 13 | noumea

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(city_loc)
city_df.head()
# Out:
#         City Country        Date  Longitude  Latitude  Max Temperature  \
# 0   carballo      ES  1584230932      -8.69     43.21            46.00
# 1    ushuaia      AR  1584230846     -68.30    -54.80            53.60
# 2     padang      ID  1584230933     100.35     -0.95            69.39
# 3     eureka      US  1584230933    -124.16     40.80            48.99
# 4  la orilla      MX  1584230933    -102.23     17.98            81.19
#
#    Humidity  Cloudiness  Wind speed
# 0       100           6        5.82
# 1        58          40        3.36
# 2        92          67        4.65
# 3        75          90        8.05
# 4        70          23        7.27

# %%
# Extract relevant fields from the data frame
lats = city_df["Latitude"]
max_temps = city_df["Max Temperature"]
humidity = city_df["Humidity"]
cloudiness = city_df["Cloudiness"]
wind_speed = city_df["Wind speed"]

# %%
# Export the City_Data into a csv
city_df.to_csv(output_data_file, index_label="City_ID")
# Show Record Count
city_df.count()
# Out:
# City               571
# Country            571
# Date               571
# Longitude          571
# Latitude           571
# Max Temperature    571
# Humidity           571
# Cloudiness         571
# Wind speed         571
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lats, max_temps, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75)
plt.title("Max Temperature v Latitude (03/14/20)")
plt.xlabel("Max Temperature (Farenheit)")
plt.ylabel("Latitude")
print("This scatter plot shows the relationship between the maximum temperature and latitude")
# Out:
# This scatter plot shows the relationship between the maximum temperature and latitude

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lats,humidity, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75)
plt.title("Latitude v Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print("This scatter plot shows the relationship between the latitude and humidity")
# Out:
# This scatter plot shows the relationship between the latitude and humidity

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lats, cloudiness, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75)
plt.title("Latitude v Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print("This scatter plot shows the relationship between the latitude and cloudliness")
# Out:
# This scatter plot shows the relationship between the latitude and cloudliness

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(lats,wind_speed, marker="o", facecolors="red", edgecolors="black",
           alpha=0.75)
plt.title("latitude vs. wind speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print("This scatter plot shows the relationship between the latitude and wind speed")
# Out:
# This scatter plot shows the relationship between the latitude and wind speed

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = city_df.loc[pd.to_numeric(city_df["Latitude"]).astype(float) > 0, :]
southern_df = city_df.loc[pd.to_numeric(city_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
